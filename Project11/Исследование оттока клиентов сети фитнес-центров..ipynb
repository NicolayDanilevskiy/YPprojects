# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!👋</b>
#
# Меня зовут Лев Беднягин, я буду ревьюером твоего проекта. Предлагаю общаться на "ты", но если это неудобно, обязательно скажи об этом!
#
# Ниже ты найдешь мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами. Пожалуйста, не удаляй их, они будут особенно полезны для нашей работы в случае повторной проверки проекта. Ты можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев, чтобы мы не запутались. 😉
#
# Мои комментарии могут выглядить, например, вот так:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к практике. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта." data-toc-modified-id="Описание-проекта.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта.</a></span></li><li><span><a href="#Описание-данных." data-toc-modified-id="Описание-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных.</a></span></li><li><span><a href="#Импорт-библиотек-и-предобработка-данных." data-toc-modified-id="Импорт-библиотек-и-предобработка-данных.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Импорт библиотек и предобработка данных.</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек-и-загрузка-данных-в-переменную." data-toc-modified-id="Импорт-библиотек-и-загрузка-данных-в-переменную.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Импорт библиотек и загрузка данных в переменную.</a></span></li><li><span><a href="#Предварительный-анализ-данных." data-toc-modified-id="Предварительный-анализ-данных.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Предварительный анализ данных.</a></span></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Предобработка данных.</a></span></li><li><span><a href="#Вывод-по-разделу." data-toc-modified-id="Вывод-по-разделу.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод по разделу.</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных-(EDA)." data-toc-modified-id="Исследовательский-анализ-данных-(EDA).-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных (EDA).</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался." data-toc-modified-id="Посмотрим-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался.</a></span></li><li><span><a href="#Построим-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)." data-toc-modified-id="Построим-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток).-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток).</a></span></li><li><span><a href="#Построим-матрицу-корреляций-и-отобразим-её." data-toc-modified-id="Построим-матрицу-корреляций-и-отобразим-её.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Построим матрицу корреляций и отобразим её.</a></span></li><li><span><a href="#Вывод-по-разделу." data-toc-modified-id="Вывод-по-разделу.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вывод по разделу.</a></span></li></ul></li><li><span><a href="#Построим-модель-прогнозирования-оттока-клиентов." data-toc-modified-id="Построим-модель-прогнозирования-оттока-клиентов.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Построим модель прогнозирования оттока клиентов.</a></span><ul class="toc-item"><li><span><a href="#Разбьем-данные-на-обучающую-и-валидационную-выборку-функцией-train_test_split()." data-toc-modified-id="Разбьем-данные-на-обучающую-и-валидационную-выборку-функцией-train_test_split().-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Разбьем данные на обучающую и валидационную выборку функцией <code>train_test_split()</code>.</a></span></li><li><span><a href="#Обучим-модель-на-train-выборке-двумя-способами." data-toc-modified-id="Обучим-модель-на-train-выборке-двумя-способами.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Обучим модель на train-выборке двумя способами.</a></span></li><li><span><a href="#Оценим-метрики-accuracy,-precision,-recall,-f1-и-roc_auc-для-обеих-моделей-на-валидационной-выборке.-Сравним-по-ним-модели.-Выясним-какая-модель-показала-себя-лучше-на-основании-метрик?" data-toc-modified-id="Оценим-метрики-accuracy,-precision,-recall,-f1-и-roc_auc-для-обеих-моделей-на-валидационной-выборке.-Сравним-по-ним-модели.-Выясним-какая-модель-показала-себя-лучше-на-основании-метрик?-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Оценим метрики accuracy, precision, recall, f1 и roc_auc для обеих моделей на валидационной выборке. Сравним по ним модели. Выясним какая модель показала себя лучше на основании метрик?</a></span></li><li><span><a href="#Общий-вывод-по-разделу." data-toc-modified-id="Общий-вывод-по-разделу.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Общий вывод по разделу.</a></span></li></ul></li><li><span><a href="#Сделаем-кластеризацию-клиентов." data-toc-modified-id="Сделаем-кластеризацию-клиентов.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Сделаем кластеризацию клиентов.</a></span><ul class="toc-item"><li><span><a href="#Стандартизируем-данные." data-toc-modified-id="Стандартизируем-данные.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Стандартизируем данные.</a></span></li><li><span><a href="#Построим-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисуем-дендрограмму." data-toc-modified-id="Построим-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисуем-дендрограмму.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Построим матрицу расстояний функцией <code>linkage()</code> на стандартизованной матрице признаков и нарисуем дендрограмму.</a></span></li><li><span><a href="#Обучим-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируем-кластеры-клиентов.--Договоримся-за-число-кластеров-принять-n=5." data-toc-modified-id="Обучим-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируем-кластеры-клиентов.--Договоримся-за-число-кластеров-принять-n=5.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов.  Договоримся за число кластеров принять n=5.</a></span></li><li><span><a href="#Посмотрим-на-средние-значения-признаков-для-кластеров." data-toc-modified-id="Посмотрим-на-средние-значения-признаков-для-кластеров.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Посмотрим на средние значения признаков для кластеров.</a></span></li><li><span><a href="#Построим-распределения-признаков-для-кластеров." data-toc-modified-id="Построим-распределения-признаков-для-кластеров.-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Построим распределения признаков для кластеров.</a></span></li><li><span><a href="#Вывод-по-разделу." data-toc-modified-id="Вывод-по-разделу.-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Вывод по разделу.</a></span></li></ul></li><li><span><a href="#Итоговые-выводы-про-проекту-и-рекомендации-по-работе-с-клиентами." data-toc-modified-id="Итоговые-выводы-про-проекту-и-рекомендации-по-работе-с-клиентами.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Итоговые выводы про проекту и рекомендации по работе с клиентами.</a></span></li></ul></div>

# %% [markdown]
# # Исследование оттока клиентов сети фитнес-центров.

# %% [markdown]
# ## Описание проекта.

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
#
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо.
#
# Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся.
#
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество клиентских анкет. Наша задача — провести анализ и подготовить план действий по удержанию клиентов.
#
# А именно:
#
# - научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# - сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# - проанализировать основные признаки, наиболее сильно влияющие на отток;
# - сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#
#     1) выделить целевые группы клиентов;
#
#     2) предложить меры по снижению оттока;
#
#     3) определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# ## Описание данных.

# %% [markdown]
# Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц.
# Данные находятся в файле: `/datasets/gym_churn.csv`
#
# Набор данных включает следующие поля:
#
# - Данные клиента за предыдущий до проверки факта оттока месяц:
#     - `gender` — пол;
#     - `Near_Location` — проживание или работа в районе, где находится фитнес-центр;
#     - `Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#     - `Promo_friends` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#     - `Phone` — наличие контактного телефона;
#     - `Age` — возраст;
#     - `Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах).
#
# - Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#     - `Contract_period` — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
#     - `Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах);
#     - `Group_visits` — факт посещения групповых занятий;
#     - `Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента;
#     - `Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц;
#     - `Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
#
# - `Churn` — факт оттока в текущем месяце.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Спасибо за оформленную вводную часть, это облегчает проверку! :)

# %% [markdown]
# ## Импорт библиотек и предобработка данных.

# %% [markdown]
# ### Импорт библиотек и загрузка данных в переменную.

# %%
# Импортируем библиотеки.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import transforms
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')

# %%
# Увеличим максимальную ширину столбца.

pd.set_option('max_colwidth', 150)

# %%
# Загружаем данные в переменную

data = pd.read_csv('/datasets/gym_churn.csv')

# %% [markdown]
# ### Предварительный анализ данных.

# %%
# Процедура для предварительного анализа данных.

def data_view(df):
    display(df.info())
    display(df.head(5))
    display(df.tail(5))
    display(df.describe())
    display('Количество пустых строк:', df.isna().sum())
    display('Количество дублирующихся строк:', df.duplicated().sum())

# %%
# Рассмотрим данные в датафрейме.

data_view(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# Каких-то аномалий, пропусков и дублей предварительный анализ данных не выявил. Для удобства приведем названия столбцов к нижнему регистру и приведем к цельночисленному формату столбец `Month_to_end_contract`.

# %% [markdown]
# ### Предобработка данных.

# %%
# Приведем названия столбцов к нижнему регистру и проверим результат.

data.columns=data.columns.str.lower()
data.columns
# Out:
# Index(['gender', 'near_location', 'partner', 'promo_friends', 'phone',
#        'contract_period', 'group_visits', 'age',
#        'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
#        'avg_class_frequency_total', 'avg_class_frequency_current_month',
#        'churn'],
#       dtype='object')

# %%
# Приведем столбец к цельночисленному формату и проверим результат.

data['month_to_end_contract'] = data['month_to_end_contract'].astype(np.int64)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   month_to_end_contract              4000 non-null   int64
#  10  lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# ### Вывод по разделу.

# %% [markdown]
# - Были импоритрованы библиотеки для дальнейшей работы.
# - Данные были загружены в переменную.
# - Предварительный анализ данных не выявил аномалий, дубликатов и пропусков в предоставленном файле.
# - Названия столбцов были приведены к нижнему регистру
# - Данные в столбце `month_to_end_contract` были приведены к цельночисленному формату

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Данные считаны верно. Молодец, что проверяешь наличие дубликатов и пропусков.

# %% [markdown]
# ## Исследовательский анализ данных (EDA).

# %% [markdown]
# ### Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался.

# %%
# Сохраним средние значения признаков в отдельную переменную и проанализируем полученные данные.

data_churn = data.groupby('churn').mean().T
data_churn
# Out:
# churn                                       0           1
# gender                               0.510037    0.510839
# near_location                        0.873086    0.768143
# partner                              0.534195    0.355325
# promo_friends                        0.353522    0.183789
# phone                                0.903709    0.902922
# contract_period                      5.747193    1.728558
# group_visits                         0.464103    0.268615
# age                                 29.976523   26.989632
# avg_additional_charges_total       158.445715  115.082899
# month_to_end_contract                5.283089    1.662582
# lifetime                             4.711807    0.990575
# avg_class_frequency_total            2.024876    1.474995
# avg_class_frequency_current_month    2.027882    1.044546

# %% [markdown]
# Влияние признаков на отток клиентов:
#
# - Пол клиента не влияет на отток
# - Проживание в районе, где находится фитнес-центр, положительно влияет на отток клиентов (0.87 против 0.77)
# - Наличие партнерской программы (скидки и т.д) положительно влияет на отток клиентов (0.53 против 0.36)
# - У клиентов пришедшие по программе «приведи друга» отток ниже чем у клиентов которые пришли самостоятельно (0.35 против 0.18)
# - Наличие контактного телефона не влияет на отток клиентов
# - Средняя длительность абонемента попавших в отток в 3 раза меньше чем у клиентов в отток не попали (5.75 против 1.73)
# - Клиенты посещающие групповые занятия попадают в отток реже чем клиенты такие занятия не посещают (0.46 против 0.27)
# - Средний возраст клиентов попавшие в отток на 3 года ниже (29.98 против 26.99)
# - Клиенты попавшие в отток тратят меньше на доп.услуги (158.45 против 115.08)
# - Срок до окончания абонемента у клиентов попавших в отток меньше (5.28 против 1.66), что логично исходя и средней длительности абонемента.
# - Новые клиенты попадают в отток чаще чем клиенты пользующиеся услугами фитнес-центра несколько месяцев (время с момента первого обращения в фитнес-центр 4.71 против 0.99)
# - Среднее количество посещений фитнес-центра у клиентов попавших в отток ниже (2.02 против 1.47)
# - Среднее количество посещений фитнес-центра за последний месяц у клиентов попавших в отток ниже (2.03 против 1.04)

# %% [markdown]
# ### Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток).

# %%
# Построим столбчатые гистрограммы по числовым признакам.

numeric_feature = data.drop(columns =(['gender', 'near_location', 
                              'partner','promo_friends', 'phone',
                              'group_visits', 'contract_period', 'churn'])).columns
for col in numeric_feature:
    plt.figure(figsize=(10, 4))
    sns.histplot(data.query('churn <= 0')[col], kde=True)
    sns.histplot(data.query('churn != 0')[col], color = 'r', kde=True)
    plt.legend(labels = ('Остались', 'Отток'))
    plt.title('Распределение для признака ' + col)
    plt.show()

# %%
# Построим столбчатые графики по бинарным признакам.

for col in data[['gender', 'near_location', 'partner',
                             'promo_friends', 'phone', 'group_visits', 'contract_period', 'churn']]:
        sns.catplot(col,
                col='churn', 
                data = data,
                kind='count',
                height=2.8,
                aspect=1.5)

# %% [markdown]
# - Чем моложе клиент, тем вероятней отток.
# - Клиенты попавшие в отток тратят меньше на доп.услуги
# - Клиенты попавшие в отток, в основном, покупают абонемент на один месяц
# - Уходят, в основном, новички, если клиент проходил в зал больше 5 месяцев, то вероятность попасть в отток почти равен нулю.
# - Клиенты попавшие в отток, в основном, посещают фитнес-центр 1-2 раза в неделю
# - Если клиент посещает фитнес-центр 3.5 - 4 раза в неделю - скорее всего в отток он не попадет

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, хорошая работа с визуализацией данных!

# %% [markdown]
# ### Построим матрицу корреляций и отобразим её.

# %%
# Построим тепловую карту корреляций признаков.

plt.figure(figsize=(15, 13))
sns.heatmap(data.corr(), annot=True, annot_kws={"size": 15}, fmt = '.2f')
plt.title('Тепловая карта по признакам', fontsize=18)
plt.xticks(rotation=80)
plt.yticks(rotation=20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Признаки', fontsize=14)
plt.xlabel('Признаки', fontsize=14)
# Out:
# Text(0.5, 95.09375, 'Признаки')

# %% [markdown]
# Есть мультиколлинеарные признаки - `contract_period` и `month_to_end_contract`, `avg_class_frequency_current_month` и `avg_class_frequency_total`. Есть признаки с нулевой корреляцией с целевой переменной, это `phone` и `gender`, они вообще никак не влияют на отток. Параметры которые наиболее сильно влияют на отток: `lifetime`, `avg_class_frequency_current_month`, `age`, `contract_period` и `month_to_end_contract`.

# %% [markdown]
# ### Вывод по разделу.

# %% [markdown]
# - Пол клиента не влияет на отток
# - Проживание в районе, где находится фитнес-центр, положительно влияет на отток клиентов (0.87 против 0.77)
# - Наличие партнерской программы (скидки и т.д) положительно влияет на отток клиентов (0.53 против 0.36)
# - У клиентов пришедшие по программе «приведи друга» отток ниже чем у клиентов которые пришли самостоятельно (0.35 против 0.18)
# - Наличие контактного телефона не влияет на отток клиентов
# - Средняя длительность абонемента попавших в отток в 3 раза меньше чем у клиентов в отток не попали (5.75 против 1.73)
# - Клиенты посещающие групповые занятия попадают в отток реже чем клиенты такие занятия не посещают (0.46 против 0.27)
# - Средний возраст клиентов попавшие в отток на 3 года ниже (29.98 против 26.99). Чем моложе клиент, тем вероятней отток.
# - Клиенты попавшие в отток тратят меньше на доп.услуги (158.45 против 115.08)
# - Срок до окончания абонемента у клиентов попавших в отток меньше (5.28 против 1.66), что логично исходя и средней длительности абонемента.
# - Новые клиенты попадают в отток чаще чем клиенты пользующиеся услугами фитнес-центра несколько месяцев (время с момента первого обращения в фитнес-центр 4.71 против 0.99) Если клиент проходил в зал больше 5 месяцев, то вероятность попасть в отток почти равен нулю.
# - Среднее количество посещений фитнес-центра у клиентов попавших в отток ниже (2.02 против 1.47)
# - Среднее количество посещений фитнес-центра за последний месяц у клиентов попавших в отток ниже (2.03 против 1.04)
# - Клиенты попавшие в отток, в основном, покупают абонемент на один месяц
# - Есть мультиколлинеарные признаки - `contract_period` и `month_to_end_contract`, `avg_class_frequency_current_month` и `avg_class_frequency_total`. Есть признаки с нулевой корреляцией с целевой переменной, это `phone` и `gender`, они вообще никак не влияют на отток.
# - Параметры которые наиболее сильно влияют на отток: `lifetime`, `avg_class_frequency_current_month`, `age`, `contract_period` и `month_to_end_contract`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Верно! Здорово, что учитываешь мультиколлинеарность.

# %% [markdown]
# ## Построим модель прогнозирования оттока клиентов.

# %% [markdown]
# Построим модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце.

# %% [markdown]
# ### Разбьем данные на обучающую и валидационную выборку функцией `train_test_split()`.

# %% [markdown]
# Так как у нас есть сильная корреляция между несколькими признаками, что говорит о мультиколлениарности. Лучше всего избавляться от одного из таких признаков, чтобы наша модель работала объективно.

# %%
# Удалим лишние признаки и сохраним полученные данные в отдельную переменную.

data_for_model = data.copy()
data_for_model = data_for_model.drop(['month_to_end_contract', 'avg_class_frequency_total'], axis=1)

# %%
# Разделим данные на признаки (матрица X) и целевую переменную (y).

X = data_for_model.drop(columns=['churn'])
y = data_for_model['churn']

# %%
# Разделим выборки на обучающую и валидационную указав параметр random_state.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Проверим результат разбиения выборки

print('\tРазмер X:', X.shape)
print('\tРазмер y:', y.shape)
print('\tРазмер X_train:', X_train.shape)
print('\tРазмер y_train:', y_train.shape)
print('\tРазмер X_test:', X_test.shape)
print('\tРазмер y_test:', y_test.shape)
# Out:
# 	Размер X: (4000, 11)
# 	Размер y: (4000,)
# 	Размер X_train: (3200, 11)
# 	Размер y_train: (3200,)
# 	Размер X_test: (800, 11)
# 	Размер y_test: (800,)

# %% [markdown]
# По размерам получившихся выборок можно судить что разбиение прошло верно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Разбиение данных на обучающую и валидационную выборки выполнено верно. Для наглядности можно было бы добавить еще размеры получающихся выборок - чтобы точно быть уверенным, что разбиение произошло верно.

# %% [markdown]
# <div class="alert alert-info">
# <b> Комментарий студента</b>
#
# Добавил вывод размеров получившихся выборок.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# 👍

# %%
# Стандартизируем данные.

scaler = StandardScaler()
#scaler.fit(X_train)
#X_train_st = scaler.transform(X_train)
X_train_st = scaler.fit_transform(X_train)
X_test_st =  scaler.transform(X_test)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Стандартизацию данных на обучающей выборке может объединить в одно действие с помощью метода `fit_transform()`.

# %% [markdown]
# <div class="alert alert-info">
# <b> Комментарий студента</b>
#
# Объединил стандартизацию данных на обучающей выборке в одно действие.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# 👍

# %% [markdown]
# ### Обучим модель на train-выборке двумя способами.

# %% [markdown]
# **Логистическая регрессия:**

# %%
# Зададим алгоритм для модели логистической регрессии

lr_model = LogisticRegression(random_state = 0)

# Обучим модель

lr_model.fit(X_train_st, y_train)

# Воспользуемся уже обученной моделью, чтобы сделать прогнозы

lr_predictions = lr_model.predict(X_test_st)
lr_probabilities = lr_model.predict_proba(X_test_st)[:,1]

# %% [markdown]
# **Случайный лес:**

# %%
# Зададим алгоритм для новой модели на основе алгоритма случайного леса

rf_model = RandomForestClassifier(n_estimators = 100,random_state = 0)

# Обучим модель случайного леса

rf_model.fit(X_train_st, y_train)

# Воспользуемся уже обученной моделью, чтобы сделать прогнозы

rf_predictions = rf_model.predict(X_test_st)
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# %% [markdown]
# ### Оценим метрики accuracy, precision, recall, f1 и roc_auc для обеих моделей на валидационной выборке. Сравним по ним модели. Выясним какая модель показала себя лучше на основании метрик?

# %% [markdown]
# - Accuracy: доля правильных ответов
# - Precision: точность (англ. precision)
# - Recall: полнота
# - F1_score: баланс между Precision and Recall
# - ROC_AUC: доля оценки качества классификатора

# %%
# Напишем функцию для вывода метрик.

def print_all_metrics(y_true, y_pred, y_proba, title):
    print(title)
    print('\tAccuracy: {:.2f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.2f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.2f}'.format(recall_score(y_true, y_pred)))
    print('\tF1: {:.2f}'.format(f1_score(y_true, y_pred)))
    print('\tROC_AUC: {:.2f}'.format(roc_auc_score(y_true, y_proba)))

# %% [markdown]
# Рассчитаем вектор прогнозов с учётом порога, равного 0.4. Cравним с метриками, полученными при автоматическом расчёте классов.

# %%
# Выберем вручную уровень отсечения.

threshold = 0.4

# На основании вероятностей и соотношения классов рассчитаем predict.

lr_custom_predictions = [0 if i<threshold else 1 for i in lr_probabilities]
rf_custom_predictions = [0 if i<threshold else 1 for i in rf_probabilities]

# %%
# Выведем все метрики.

print_all_metrics(y_test, lr_predictions, lr_probabilities, 'Метрики для модели логистической регрессии:')
print_all_metrics(y_test, rf_predictions, rf_probabilities, 'Метрики для модели случайного леса:')
print_all_metrics(y_test, lr_custom_predictions, lr_probabilities,
                  'Метрики для модели логистической регрессии с кастомным порогом:')
print_all_metrics(y_test, rf_custom_predictions, rf_probabilities,
                  'Метрики для модели случайного леса с кастомным порогом:')
# Out:
# Метрики для модели логистической регрессии:
# 	Accuracy: 0.90
# 	Precision: 0.79
# 	Recall: 0.82
# 	F1: 0.81
# 	ROC_AUC: 0.96
# Метрики для модели случайного леса:
# 	Accuracy: 0.90
# 	Precision: 0.81
# 	Recall: 0.75
# 	F1: 0.78
# 	ROC_AUC: 0.95
# Метрики для модели логистической регрессии с кастомным порогом:
# 	Accuracy: 0.91
# 	Precision: 0.77
# 	Recall: 0.87
# 	F1: 0.82
# 	ROC_AUC: 0.96
# Метрики для модели случайного леса с кастомным порогом:
# 	Accuracy: 0.89
# 	Precision: 0.76
# 	Recall: 0.84
# 	F1: 0.80
# 	ROC_AUC: 0.95

# %% [markdown]
# Модель логистической регрессии с кастомным порогом обладает самыми высокими показателями метрик. В дальнейшем для прогнозирования можно использовать модель логистической регрессии с кастомным порогом.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Обучение моделей и оценка метрик качества на валидационной выборке выполнены верно.

# %% [markdown]
# ### Общий вывод по разделу.

# %% [markdown]
# - Разбили данные на обучающую и валидационную выборку функцией `train_test_split()`
# - Обучили модель на train-выборке двумя способами: Логистическая регрессия, Случайный лес
# - Оценили метрики accuracy, precision, recall, f1 и roc_auc для обеих моделей на валидационной выборке
# - Модель логистической регрессии с кастомным порогом обладает самыми высокими показателями метрик. В дальнейшем для прогнозирования можно использовать модель логистической регрессии с кастомным порогом.

# %% [markdown]
# ##  Сделаем кластеризацию клиентов.

# %% [markdown]
# ### Стандартизируем данные.

# %%
# Стандартизируем данные.

sc = StandardScaler()
x_sc = sc.fit_transform(X)

# %% [markdown]
# ### Построим матрицу расстояний функцией `linkage()` на стандартизованной матрице признаков и нарисуем дендрограмму.

# %%
# Строим матрицу расстояний и рисуем дендрограмму.

linked = linkage(x_sc, method = 'ward')
plt.figure(figsize=(20, 15))  
dendrogram(linked, orientation='top')
plt.title('Кластеризация пользователей')
plt.show()

# %% [markdown]
# По дендрограмме наблюдается 4 цвета, то есть, если опираться на этот критерий, то оптимальной была бы величина в 4 кластера. Но фиолетовый кластер получается слишком большим. На расстоянии ~60, в фиолетовом кластере наблюдается разделение на две линии. Таким образом, можно предположить, что оптимальное число кластеров - 5.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Построение дендрограммы выполнено верно.

# %% [markdown]
# ### Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов.  Договоримся за число кластеров принять n=5.

# %%
# Обучим модель кластеризации по алгоритму K-Means.

km = KMeans(n_clusters = 5, random_state=0)
labels = km.fit_predict(x_sc)
data_for_model['cluster'] = labels

# %%
# Посмотрим на размеры получившихся кластеров.

data_for_model['cluster'].value_counts()
# Out:
# 2    1064
# 3    1007
# 0     985
# 1     558
# 4     386
# Name: cluster, dtype: int64

# %% [markdown]
# ### Посмотрим на средние значения признаков для кластеров.

# %%
# Выведем средние значения признаков для кластеров.

data_for_model.groupby('cluster').mean().T
# Out:
# cluster                                     0           1           2  \
# gender                               0.496447    0.500000    0.500940
# near_location                        0.995939    0.000000    1.000000
# partner                              0.892386    0.489247    0.217105
# promo_friends                        1.000000    0.078853    0.072368
# phone                                1.000000    1.000000    1.000000
# contract_period                      6.922843    2.994624    2.010338
# group_visits                         0.524873    0.232975    0.277256
# age                                 29.606091   28.679211   27.583647
# avg_additional_charges_total       153.424651  137.125763  119.339956
# lifetime                             4.283249    2.974910    1.922932
# avg_class_frequency_current_month    1.919520    1.597146    1.203319
# churn                                0.119797    0.403226    0.563910
#
# ...

# %% [markdown]
# По количеству клиентов попавших в отток лидируют кластеры 1 и 2:
#
# - Женщин и мужчин в данных кластерах примерно поровну.
# - В кластер 1 попали клиенты проживающие или работающие вне района нахождения фитнес-центра, в кластер 2 наоборот.
# - Средний возраст клиентов в кластерах 27-28 лет.
# - Клиенты в кластерах в среднем посещают фитнес-центр уже 2-3 месяца.
# - В среднем, клиенты этих кластеров платят за дополнительные услуги меньше клиентов остальных кластеров.
# - Среднее количество посещений фитнес-центра в этих кластерах 1.2 - 1.6 раза в неделю.
# - Клиенты данных кластеров посещают групповые занятия реже клиентов других кластеров.
#
# Лучшие показатели по оттоку клиентов показал кластер 3:
#
# - Почти все клиенты попавшие в кластер проживают или работают в районе расположения фитнес-центра.
# - Средний возраст клиентов попавший в данный кластер самый высокий из всех кластеров - 31 год.
# - В среднем, клиенты кластера посещают фитнес-центр больше 5 месяцев.
# - В среднем, клиенты кластера платят за дополнительные услуги больше клиентов остальных кластеров.
# - Среднее количество посещений фитнес-центра клиентами кластера выше чем в других кластерах - 2.3 раза в неделю.
# - Клиенты данного кластера посещают групповые занятия чаще клиентов попавших в другие кластеры.

# %% [markdown]
# ### Построим распределения признаков для кластеров.

# %%
# Построим графики для небинарных признаков

for column in ['age', 'contract_period', 'lifetime', 'avg_class_frequency_current_month', 'avg_additional_charges_total']:
    plt.figure(figsize=(10, 5))
    plt.title(column)   
    sns.kdeplot(data_for_model.query('cluster==0')[column], label = 'Кластер 0')
    sns.kdeplot(data_for_model.query('cluster==1')[column], label = 'Кластер 1')
    sns.kdeplot(data_for_model.query('cluster==2')[column], label = 'Кластер 2')
    sns.kdeplot(data_for_model.query('cluster==3')[column], label = 'Кластер 3')
    sns.kdeplot(data_for_model.query('cluster==4')[column], label = 'Кластер 4')
    
    plt.legend()
    plt.show()

# %%
# Построим графики для бинарных признаков

for column in ['gender', 'near_location', 'partner', 'promo_friends', 'phone', 'group_visits', 'churn']:
    plt.figure(figsize=(10, 3.3))
    sns.countplot(x = data_for_model[column], hue='cluster', data=data_for_model)
    plt.title(column)
    plt.show()

# %% [markdown]
# Для клиентов попавших в кластер 0 характерно:
#
# - Почти все клиенты пришли по партнерской программе
# - Все клиенты изначально пришли по промо-коду
# - Почти все клиенты либо проживают либо работают в районе где находится фитнес-центр
# - Почти половина клиентов кластера посещают групповые занятия
# - Значительная доля клиентов кластера владеет абонементами на 12 месяцев
# - Незначительные значения оттока клиентов в кластере
#
# Для клиентов попавших в кластер 1 характерно:
#
# - Все клиента кластера проживают или работают вне района где находится фитнес-центр
# - Почти половина клиентов пришли по партнерской программе
# - Незначительная доля клиентов кластера ходят на групповые занятия
# - Значительная доля клиентов владеет абониментами на 1 месяц
# - Большие значения оттока клиентов в кластере
#
# Для клиентов попавших в кластер 2 характерно:
#
# - Все клиенты либо проживают либо работают в районе где находится фитнес-центр
# - Незначительные доли клиентов кластера пришли по промо-коду или партнерской программе
# - Незначительная доля клиентов кластера ходят на групповые занятия
# - Большинство клиентов владеет абонементом на 1 месяц
# - Кластер лидирует по количеству клиентов попавших в отток
#
# Для клиентов попавших в кластер 3 характерно:
#
# - Почти все клиенты либо проживают либо работают в районе где находится фитнес-центр
# - Почти треть клиентов пришли по партнерской программе, при этом почти нет клиентов пришедших по промо-коду
# - Большая часть клиентов кластера посещают групповые занятия
# - В основном клиенты кластера владеют абонементами на 1 или 12 месяцев
# - Лучший кластер с точки зрения оттока клиентов(самые маленькие значения оттока)
#
# Для клиентов попавших в кластер 4 характерно:
#
# - Значительная часть клиентов кластера либо проживают либо работают в районе где находится фитнес-центр
# - Почити половина клиентов пришла по партнерской программе
# - Треть клиентов пришла по промо-коду
# - Все клиенты кластера не указали контактный телефон
# - Чуть меньше половины клиентов кластера посещают групповые занятия
# - Клиенты кластера предпочитают брать абонементы на 1 месяц
# - Достаточно большие значения оттока клиентов в кластере(около 1/4)

# %% [markdown]
# ### Вывод по разделу.

# %% [markdown]
# - Построили матрицу расстояний
# - Нарисовали дендрограмму
# - Обучили модель кластеризации на основании алгоритма K-Means и спрогнозировали кластеры клиентов
# - Поделили клиентов на 5 кластеров
# - Определили характеристики полученных кластеров
# - Лучшими, с точки зрения оттока клиентов, оказались кластеры 0 и 3
# - Худшими, с точки зрения оттока клиентов, оказались кластеры 1 и 2

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Кластеризация с помощью метода KMeans и описание полученных кластеров выполнены верно, хорошая работа!

# %% [markdown]
# ## Итоговые выводы про проекту и рекомендации по работе с клиентами.

# %% [markdown]
#    В ходе работы по проекту были изучены данные 4000 клиентов сети фитнес-центров «Культурист-датасаентист».
# Фитнес-клуб посещают клиенты в возрасте от 18 до 41 года, средний возраст составляет 29 лет. Клиенты по полу распределены приблизительно равномерно (51% / 49%). Половина клиентов пришли по партнерской программе. Треть клиентов пришли по промо-коду в рамках акции "приведи друга". На групповые занятия ходят 41% клиентов. 15% клиентов приезжают заниматься из других районов.
# Всего лишь 10% клиентов не оставили контактный номер телефона. В общей массе клиенты посещают фитнес-центр в среднем около 2 раз в неделю. Больше половины клиентов (55% или 2207 человек) предпочитают покупать короткие абонементы на 1 месяц, но также есть меньшая по размеру группа с полугодовыми и годовыми абонементами (21% и 24% соответственно).
#
# **Влияние признаков на отток клиентов:**
#
# - Пол клиента не влияет на отток
# - Проживание в районе, где находится фитнес-центр, положительно влияет на отток клиентов (0.87 против 0.77)
# - Наличие партнерской программы (скидки и т.д) положительно влияет на отток клиентов (0.53 против 0.36)
# - У клиентов пришедшие по программе «приведи друга» отток ниже чем у клиентов которые пришли самостоятельно (0.35 против 0.18)
# - Наличие контактного телефона не влияет на отток клиентов
# - Средняя длительность абонемента попавших в отток в 3 раза меньше чем у клиентов в отток не попали (5.75 против 1.73)
# - Клиенты посещающие групповые занятия попадают в отток реже чем клиенты такие занятия не посещают (0.46 против 0.27)
# - Средний возраст клиентов попавшие в отток на 3 года ниже (29.98 против 26.99). Чем моложе клиент, тем вероятней отток.
# - Клиенты попавшие в отток тратят меньше на доп.услуги (158.45 против 115.08)
# - Срок до окончания абонемента у клиентов попавших в отток меньше (5.28 против 1.66), что логично исходя и средней длительности абонемента.
# - Новые клиенты попадают в отток чаще чем клиенты пользующиеся услугами фитнес-центра несколько месяцев (время с момента первого обращения в фитнес-центр 4.71 против 0.99) Если клиент проходил в зал больше 5 месяцев, то вероятность попасть в отток почти равен нулю.
# - Среднее количество посещений фитнес-центра у клиентов попавших в отток ниже (2.02 против 1.47)
# - Среднее количество посещений фитнес-центра за последний месяц у клиентов попавших в отток ниже (2.03 против 1.04)
# - Клиенты попавшие в отток, в основном, покупают абонемент на один месяц
# - Есть мультиколлинеарные признаки - `contract_period` и `month_to_end_contract`, `avg_class_frequency_current_month` и `avg_class_frequency_total`. Есть признаки с нулевой корреляцией с целевой переменной, это `phone` и `gender`, они вообще никак не влияют на отток.
# - Параметры которые наиболее сильно влияют на отток: `lifetime`, `avg_class_frequency_current_month`, `age`, `contract_period` и `month_to_end_contract`.
#
# **Модель прогнозирования оттока:**
#
# - Разбили данные на обучающую и валидационную выборку функцией `train_test_split()`
# - Обучили модель на train-выборке двумя способами: Логистическая регрессия, Случайный лес
# - Оценили метрики accuracy, precision, recall, f1 и roc_auc для обеих моделей на валидационной выборке
# - Модель логистической регрессии с кастомным порогом обладает самыми высокими показателями метрик. В дальнейшем для прогнозирования можно использовать модель логистической регрессии с кастомным порогом.
#
# **Кластеризация клиентов:**
#
# - Построили матрицу расстояний
# - Нарисовали дендрограмму
# - Обучили модель кластеризации на основании алгоритма K-Means и спрогнозировали кластеры клиентов
# - Поделили клиентов на 5 кластеров
# - Определили характеристики полученных кластеров
# - Лучшими, с точки зрения оттока клиентов, оказались кластеры 0 и 3
# - Худшими, с точки зрения оттока клиентов, оказались кластеры 1 и 2
#
# **Рекомендации по работе с клиентами:**
#
# - Фитнес-центрам рекомендуется мотивировать клиентов заключать договора на более длительный срок, например, за счет снижения стоимости в перерасчете за месяц. Как правило клиенты проходившие в фитнес-центр больше 5 месяцев не подвержены оттоку. Можно попробовать ввести сезонный абонемент например на 3 месяца.
# - Расширить перечень групповых занятий. Провести опрос клиентов на предмет того, какие бы занятия им были бы интересны. Можно предложить бесплатные пробные групповые занятия.
# - Поработать над расширением партнерской программы, предложить интересные условия для работодателей в районах расположения фитнес-центров.
# - Ввести программу лояльности для постоянных клиентов которые посещают фитнес-центр более полугода.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Рассуждение и вывод сформулированы подробно и с обоснованием, рекомендации даны.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Николай, спасибо за твой проект! Тобой приложено много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты большой молодец!
#
# Отмечу, что критических замечаний нет, возвращаю проект, чтобы у тебя была возможность задать вопросы по ревью.

# %% [markdown]
# <div class="alert alert-info">
# <b> Комментарий студента</b>
#
# Лев, спасибо за ревью!
#
# Вопросов по ревью у меня не возникло.
#
# Немного подправил код в пункте 5.1 согласно твоим комментариям.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# Николай, большое спасибо за твою работу! Удачи в изучении следующих тем и в новых проектах! 😉
