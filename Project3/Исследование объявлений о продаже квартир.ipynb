# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Привет еще раз. Спасибо, что доделал работу. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет, Николай! Спасибо, что прислал задание:) Меня зовут Слепцов Артем и я буду проверять твой проект) Ты проделал большую работу над проектом. Он выполнен уже на достойном уровне. Однако есть моменты, которые еще можно улучшить. Будет здорово, если ты, надеюсь, не против, если я буду на ты, будешь отвечать на комментарии и участвовать в диалоге. Если обращение на ты неприемлемо, то прошу сообщить.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках:
#
# <div class="alert alert-success">Успех: Если фон комментария зелёный - всё сделано правильно. Рекомендации укажу таким же цветом;</div>
#
# <div class="alert alert-warning">Совет: Оранжевый - некритичные замечания;</div>
#
# <div class="alert alert-danger">Ошибка: Красный - нужно переделать. </div>
#
# Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта. Свои же комментарии ты можешь обозначать любым заметным способом.
#
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла." data-toc-modified-id="Изучение-данных-из-файла.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла.</a></span><ul class="toc-item"><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных.</a></span><ul class="toc-item"><li><span><a href="#Переименование-и-упорядочивание-столбцов." data-toc-modified-id="Переименование-и-упорядочивание-столбцов.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Переименование и упорядочивание столбцов.</a></span></li><li><span><a href="#Работа-с-пропусками-и-типом-данных." data-toc-modified-id="Работа-с-пропусками-и-типом-данных.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Работа с пропусками и типом данных.</a></span></li><li><span><a href="#Поиск-дублей." data-toc-modified-id="Поиск-дублей.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Поиск дублей.</a></span></li><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра." data-toc-modified-id="Цена-квадратного-метра.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена квадратного метра.</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления." data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления.</a></span></li><li><span><a href="#Категоризация-по-этажам." data-toc-modified-id="Категоризация-по-этажам.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Категоризация по этажам.</a></span></li><li><span><a href="#Соотношение-площадей." data-toc-modified-id="Соотношение-площадей.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Соотношение площадей.</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучаем-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Изучаем-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучаем следующие параметры: площадь, цена, число комнат, высота потолков.</a></span></li><li><span><a href="#Изучение-времени-продажи-квартир." data-toc-modified-id="Изучение-времени-продажи-квартир.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучение времени продажи квартир.</a></span></li><li><span><a href="#Уберем-редкие-и-выбивающиеся-значения." data-toc-modified-id="Уберем-редкие-и-выбивающиеся-значения.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберем редкие и выбивающиеся значения.</a></span></li><li><span><a href="#Факторы-влияющие-на-стоимость-квартиры." data-toc-modified-id="Факторы-влияющие-на-стоимость-квартиры.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Факторы влияющие на стоимость квартиры.</a></span></li><li><span><a href="#Выберем-10-населённых-пунктов-с-наибольшим-числом-объявлений." data-toc-modified-id="Выберем-10-населённых-пунктов-с-наибольшим-числом-объявлений.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберем 10 населённых пунктов с наибольшим числом объявлений.</a></span></li><li><span><a href="#Выделим-квартиры-в-Санкт-Петербурге.-Создадим-столбец-с-расстоянием-до-центра-в-километрах." data-toc-modified-id="Выделим-квартиры-в-Санкт-Петербурге.-Создадим-столбец-с-расстоянием-до-центра-в-километрах.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Выделим квартиры в Санкт-Петербурге. Создадим столбец с расстоянием до центра в километрах.</a></span></li><li><span><a href="#Анализ-предложений-в-центре-Санк-Петербурга." data-toc-modified-id="Анализ-предложений-в-центре-Санк-Петербурга.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Анализ предложений в центре Санк-Петербурга.</a></span></li></ul></li><li><span><a href="#Общий-вывод." data-toc-modified-id="Общий-вывод.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод.</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Описание данных**
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Здорово, что каждому пункту вводной информации ты уделил внимание.
#
# </div>

# %% [markdown]
# ## Изучение данных из файла.

# %% [markdown]
# Импортируем библиотеки и изучим данные в предоставленом файле с данными.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: Я заметил, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой работы рекомендую перезапускать ноутбук, чтобы убедиться, что все ячейки выполняются корректно.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Поправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Отлично!
#
# </div>

# %% [markdown]
# **Импорт библиотек.**

# %%
# Импортируем библиотеки.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Чтение данных и сохранение их в переменной.**

# %%
# Cохраним данные из файла в переменной.
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: Старайся разделять логически разные вещи (минимально):
#
#     - импорт библиотек
#     - открытие данных
#     - рабочий код
#
# Каждое действие стоит проводить в своей ячейке.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Поправил
# </div>

# %% [markdown]
# **Предварительный анализ данных.**

# %%
# Посмотим первые 10 строк датафрейма
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
# Посмотрим последние 10 строк датафрейма
data.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23689            13   3550000.0       35.30  2018-02-28T00:00:00      1
# 23690             3   5500000.0       52.00  2018-07-19T00:00:00      2
# 23691            11   9470000.0       72.90  2016-10-13T00:00:00      2
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23693             9   4600000.0       62.40  2016-08-05T00:00:00      3
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23689            2.86          15.0         16.3      4          NaN  ...
# ...

# %%
# Посмотрим описательную статистику по датафрейму
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %%
# Посмотрим информацию по столбцам датафрейма
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# ### Вывод.

# %% [markdown]
# **Предварительные выводы.**
# - столбец `first_day_exposition` - тип object, должен быть datetime.
# - столбец `ceiling_height` - пропущенные значения.
# - столбец `floors_total` - тип float64, должен быть int. Пропущенные значения.
# - столбец `is_apartment` - тип object, должен быть bool. Пропущенные значения.
# - столбец `living_area` - Пропущенные значения.
# - столбец `kitchen_area` - Пропущенные значения.
# - столбец `balcony` - тип float64, можно сделать int. Пропущенные значения.
# - столбец `locality_name` - Пропущенные значения.
# - столбец `airports_nearest` - Пропущенные значения.
# - столбец `cityCenters_nearest` - Пропущенные значения.
# - столбец `parks_around3000` - тип float64, можно сделать int. Пропущенные значения.
# - столбец `parks_nearest` - Пропущенные значения.
# - столбец `ponds_around3000` - тип float64, можно сделать int. Пропущенные значения.
# - столбец `ponds_nearest` - Пропущенные значения.
# - столбец `days_exposition` - тип float64, можно сделать int. Пропущенные значения.
# - названия некоторых столбцов лучше поменять - для лучшего понимания их содержания.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Подумай также о возможных причинах появления пропусков, а также о том, являются ли они случайными или нет. Можно высказать предварительные варианты их обработки.
#
# Первый взгляд на таблицу выполнен.
#
# </div>

# %% [markdown]
# ## Предобработка данных.

# %% [markdown]
# ### Переименование и упорядочивание столбцов.

# %% [markdown]
# **Сначала поработаем с названием столбцов. Сделаем их более понятными.**

# %%
# Выведем названия столбцов
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
# Переименовываем столбцы
data.rename(columns = {'total_area' : 'total_area_m2',
                       'rooms' : 'number_of_rooms',
                       'ceiling_height' : 'ceiling_height_m',
                       'floors_total' : 'total_floors_in_house',
                       'living_area' : 'living_area_m2',
                       'studio' : 'is_studio',
                       'open_plan' : 'is_open_plan',
                       'kitchen_area' : 'kitchen_area_m2',
                       'balcony' : 'number_of_balconies',
                       'locality_name' : 'location_name',
                       'airports_nearest' : 'nearest_airport_m',
                       'cityCenters_nearest' : 'city_center_m',
                       'parks_around3000' : 'parks_number_within_3km',
                       'parks_nearest' : 'nearest_park_m',
                       'ponds_around3000' : 'ponds_number_within_3km',
                       'ponds_nearest' : 'nearest_pond_m'}, inplace = True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Правильно, что ты используешь rename для операции переименования столбцов.
#
# </div>

# %%
# Проверяем названия столбцов после переименования
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area_m2', 'first_day_exposition',
#        'number_of_rooms', 'ceiling_height_m', 'total_floors_in_house',
#        'living_area_m2', 'floor', 'is_apartment', 'is_studio', 'is_open_plan',
#        'kitchen_area_m2', 'number_of_balconies', 'location_name',
#        'nearest_airport_m', 'city_center_m', 'parks_number_within_3km',
#        'nearest_park_m', 'ponds_number_within_3km', 'nearest_pond_m',
#        'days_exposition'],
#       dtype='object')

# %% [markdown]
# **Поработаем с порядком столбцов в датафрейме**

# %%
# Упорядочим столбцы в датафрейме.
data = data[[
    'total_images',
    'first_day_exposition',
    'days_exposition',
    'last_price',
    'location_name',
    'is_apartment',
    'is_studio',
    'is_open_plan',
    'total_floors_in_house',
    'floor',
    'number_of_rooms',
    'number_of_balconies',
    'total_area_m2',
    'living_area_m2',
    'kitchen_area_m2',
    'ceiling_height_m',
    'city_center_m',
    'nearest_airport_m',
    'nearest_park_m',
    'parks_number_within_3km',
    'nearest_pond_m',
    'ponds_number_within_3km'
    ]]

# %%
# Проверим что получилось
data.head()
# Out:
#    total_images first_day_exposition  days_exposition  last_price  \
# 0            20  2019-03-07T00:00:00              NaN  13000000.0
# 1             7  2018-12-04T00:00:00             81.0   3350000.0
# 2            10  2015-08-20T00:00:00            558.0   5196000.0
# 3             0  2015-07-24T00:00:00            424.0  64900000.0
# 4             2  2018-06-19T00:00:00            121.0  10000000.0
#
#      location_name is_apartment  is_studio  is_open_plan  \
# 0  Санкт-Петербург          NaN      False         False
# 1   посёлок Шушары          NaN      False         False
# 2  Санкт-Петербург          NaN      False         False
# 3  Санкт-Петербург          NaN      False         False
# 4  Санкт-Петербург          NaN      False         False
#
#    total_floors_in_house  floor  ...  total_area_m2  living_area_m2  \
# 0                   16.0      8  ...          108.0            51.0
# 1                   11.0      1  ...           40.4            18.6
# ...

# %% [markdown]
# ### Работа с пропусками и типом данных.

# %% [markdown]
# **Поработаем со всеми столбцами датафрейма на предмет пропусков, аномальных значений и типов данных.**

# %% [markdown]
# **Проверим столбец `total_images`.**
#
# Вряд ли данные нам пригодятся, но все равно посмотрим.

# %%
# Посмотрим уникальные значения в столбце.
data['total_images'].value_counts().sort_index(ascending=True)
# Out:
# 0     1059
# 1      872
# 2      640
# 3      769
# 4      986
# 5     1301
# 6     1482
# 7     1521
# 8     1585
# 9     1725
# 10    1798
# 11    1362
# 12    1225
# 13    1015
# 14     986
# 15     948
# 16     761
# 17     650
# 18     642
# 19     603
# 20    1694
# 21      12
# 22       8
# 23      16
# 24       8
# 25       1
# 26       5
# 27       2
# 28       4
# 29       3
# 30       2
# 31       2
# 32       4
# 35       2
# 37       1
# 39       1
# 42       1
# 50       3
# Name: total_images, dtype: int64

# %% [markdown]
# Никаких аномалий и пропусков в столбце `total_images` не замечено.

# %% [markdown]
# **Посмотрим данные в столбце `first_day_exposition`.**
#
# Как было выявлено в предварительном анализе данных в датафрейме, столбец нужно привести к формату datetime и оставить только дату, время везде нулевое.

# %%
# Меняем формат столбца.
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')
# Проверим изменения.
data.info()
# Посмотрим первые 5 строк датафрейма после изменений.
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images               23699 non-null int64
# first_day_exposition       23699 non-null datetime64[ns]
# days_exposition            20518 non-null float64
# last_price                 23699 non-null float64
# location_name              23650 non-null object
# is_apartment               2775 non-null object
# is_studio                  23699 non-null bool
# is_open_plan               23699 non-null bool
# total_floors_in_house      23613 non-null float64
# floor                      23699 non-null int64
# number_of_rooms            23699 non-null int64
# number_of_balconies        12180 non-null float64
# total_area_m2              23699 non-null float64
# living_area_m2             21796 non-null float64
# kitchen_area_m2            21421 non-null float64
# ceiling_height_m           14504 non-null float64
# city_center_m              18180 non-null float64
# ...

# %% [markdown]
# Формат столбца `first_day_exposition` поменяли, аномалий не замечено.

# %% [markdown]
# **Посмотрим столбец `days_exposition`.**
#
# Как было выявлено в предварительном анализе данных в датафрейме, в столбце были выявлены пропуски.

# %%
# Посмотрим количество пропусков.
data['days_exposition'].isna().sum()
# Out:
# 3181

# %%
# Посмотрим % пропусков в столбце.
data['days_exposition'].isna().sum()/data.shape[0]*100
# Out:
# 13.422507278788135

# %% [markdown]
# Процент пропусков в столбце достаточно большой. Попробуем разобраться в причинах возникновения пропусков.

# %%
# Выведем 15 первых строк с пропусками в столбце days_exposition.
# Возможно получится найти закономерность возникновения пропусков.
data[data['days_exposition'].isna()].head(15)
# Out:
#      total_images first_day_exposition  days_exposition  last_price  \
# 0              20           2019-03-07              NaN  13000000.0
# 7               5           2019-04-18              NaN   7915000.0
# 44             13           2018-11-18              NaN   5350000.0
# 45             17           2018-12-02              NaN   5200000.0
# 46             17           2019-01-31              NaN   6600000.0
# 49              1           2018-11-22              NaN   3050000.0
# 52             20           2017-09-22              NaN  11795000.0
# 71             20           2019-03-27              NaN   4850000.0
# 81              9           2018-12-27              NaN  10949000.0
# 84             11           2019-03-13              NaN   2400000.0
# 87             19           2019-04-23              NaN   4999000.0
# 88              0           2019-04-09              NaN   1700000.0
# 101             4           2019-03-23              NaN   3000000.0
# ...

# %% [markdown]
# Тут сложно найти какую-то закономерность. Исходя из изначального описания данных в столбце - пропуски, скорее всего, связаны с тем что объявления еще не сняты(действующие объявления). Но точной информации на данный счет у нас нет. Для дальнейшего анализа нам эти данные будут только мешать, так что сохраним их в отдельную таблицу и уберем из основного датасета. ~~Для удобства можно заполнить пропуски нулями и изменить формат столбца. В будущем будем учитывать что значения с 0 - это действующие объявления.~~

# %%
# Запишем в переменную максимальную дату размещения объявления в датафрейме.
# max_date_of_exposition = data['first_day_exposition'].max()
# Выведем результат.
# max_date_of_exposition

# %%
# Заменим пропуски в days_exposition и заменим тип данных
# data['days_exposition'] = data['days_exposition'].fillna((pd.to_datetime(max_date_of_exposition) - data['first_day_exposition']).dt.days).astype('int')

# %%
# Проверим количество пропусков после их заполненения.
# data['days_exposition'].isna().sum()

# %%
# Сохраним строки с пропусками в отдельную таблицу. Эти данные могут пригодиться для выяснения причин появления пропусков.
days_exposition_null = data[data['days_exposition'].isna()]
# Удаляем строки с пустыми значениями в наименованиях населенных пунктов.
data = data.dropna(subset=['days_exposition']).reset_index(drop=True)
# Проверяем результат.
data['days_exposition'].isna().sum()
# Out:
# 0

# %%
# меняем тип данных в столбце.
data['days_exposition'] = data['days_exposition'].astype('int')

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка: Да, с больщой долей вероятности такие объявления относятся к незакрытым. Однако этот момент стоит доказать. Посмотри внимательнее на распределение пропусков в данном столбце во времени, т.е. относительно дня выставления квартиры на продажу. Заполнять мы, строго говоря, имеем право только когда данные пропущены совершенно случайно (MCAR) - тогда заполнение не повлияет на характер связи между заполняемой переменной и остальными. Относятся ли пропуски в данном столбце к данному типу пропусков? Заполнять пропуски нулем не стоит.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сначала хотел заполнить пропуски разницей между максимальной датой размещения и датой размещения объявления с пропусками, но потом понял что это повлияет на результаты исследования "Изучение времени продажи квартир". Так что сохранил эти данные в отдельной таблице и убрал их из общей выборки чтобы они не мешали дальнейшему анализу(нас же интересуют именно завершенные сделки с недвижимостью).
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Ок, логика ясна. Могу с ней согласиться, т.к. действительно, эти объявления очень похожи на незакрытые.
#
# </div>

# %% [markdown]
# **Посмотрим столбец `last_price`.**
#
# В данном столбце ранее не было выявлено пропусков. Просто поменяем формат столбца на int, копейки нам вряд ли понадобятся в будущих расчетах.

# %%
# меняем тип данных в столбце.
data['last_price'] = data['last_price'].astype('int')
# проверим результат.
data['last_price']
# Out:
# 0         3350000
# 1         5196000
# 2        64900000
# 3        10000000
# 4         2890000
#            ...
# 20513     9470000
# 20514     1350000
# 20515     4600000
# 20516     3100000
# 20517    11475000
# Name: last_price, Length: 20518, dtype: int64

# %% [markdown]
# Тип данных поменяли.

# %% [markdown]
# **Посмотрим столбец `location_name`.**
#
# Ранее в столбце были выявлены пропуски, плюс было бы полезно подробней изучить значения в данном столбце.

# %%
# Посмотрим уникальные значения в столбце.
data['location_name'].unique().tolist()
# Out:
# ['посёлок Шушары',
#  'Санкт-Петербург',
#  'городской посёлок Янино-1',
#  'посёлок Парголово',
#  'посёлок Мурино',
#  'Ломоносов',
#  'Сертолово',
#  'Петергоф',
#  'Пушкин',
#  'деревня Кудрово',
#  'Коммунар',
#  'Колпино',
#  'поселок городского типа Красный Бор',
#  'Гатчина',
#  'поселок Мурино',
#  'деревня Фёдоровское',
#  'Выборг',
#  'Кронштадт',
#  'Кировск',
#  'деревня Новое Девяткино',
#  'посёлок Металлострой',
#  'посёлок городского типа Сиверский',
#  'поселок Молодцово',
#  'поселок городского типа Кузьмоловский',
#  'Павловск',
#  'деревня Пикколово',
#  'Всеволожск',
#  'Кингисепп',
#  'Сестрорецк',
#  'деревня Куттузи',
#  'поселок городского типа Ефимовский',
#  'посёлок Плодовое',
#  'деревня Заклинье',
#  'поселок Торковичи',
#  'Красное Село',
#  'посёлок Понтонный',
#  'Сясьстрой',
#  'посёлок Новый Свет',
#  'Приозерск',
#  'Сланцы',
#  'село Путилово',
#  'Ивангород',
#  'Шлиссельбург',
#  'Никольское',
#  'Зеленогорск',
#  'Сосновый Бор',
# ...

# %%
# Посмотрим процент пропусков.
data['location_name'].isna().sum()/data.shape[0]*100
# Out:
# 0.23394092991519644

# %% [markdown]
# Видим несколько проблем с данными в столбце:
# - есть посёлок, есть поселок
# - есть Мурино, есть поселок Мурино
#
# Можно попробовать ё заменить на е, попробовать убрать из столбца тип поселения, удалить строки с пропусками(пропусков меньше 1% и они нам будут только мешать в будущем исследовании).

# %%
# Посмотрим количество уникальных значений в столбцах.
len(data['location_name'].unique())
# Out:
# 331

# %%
# Сохраним строки с пропусками в отдельную таблицу. Эти данные могут пригодиться для выяснения причин появления пропусков.
location_name_null = data[data['location_name'].isna()]
# Удаляем строки с пустыми значениями в наименованиях населенных пунктов.
data = data.dropna(subset=['location_name']).reset_index(drop=True)
# Проверяем результат.
data['location_name'].isna().sum()
# Out:
# 0

# %%
# Заменяем ё на е.
data['location_name'] = data['location_name'].str.replace('ё', 'е', regex=True)

# %%
# Проверим количество уникальных значений после замены.
len(data['location_name'].unique())
# Out:
# 299

# %%
# Заменим тип населенного пункта в столбце на пустое значение.
# Совсем не элегантное решение, но не смог придумать как это сделать более изящно.
data['location_name'] = data['location_name'].str.replace('городской поселок ', '')
data['location_name'] = data['location_name'].str.replace('садоводческое некоммерческое товарищество ', '')
data['location_name'] = data['location_name'].str.replace('поселок станции ', '')
data['location_name'] = data['location_name'].str.replace('садовое товарищество ', '')
data['location_name'] = data['location_name'].str.replace('поселок городского типа ', '')
data['location_name'] = data['location_name'].str.replace('коттеджный поселок ', '')
data['location_name'] = data['location_name'].str.replace('поселок при железнодорожной станции ', '')
data['location_name'] = data['location_name'].str.replace('село ', '')
data['location_name'] = data['location_name'].str.replace('деревня ', '')
data['location_name'] = data['location_name'].str.replace('поселок ', '')

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Здорово, что ты привел названия к единому виду.
#
# </div>

# %%
# Проверим количество уникальных значений в столбце.
len(data['location_name'].unique())
# Out:
# 281

# %%
# Посмотрим уникальные значения в столбце.
data['location_name'].unique().tolist()
# Out:
# ['Шушары',
#  'Санкт-Петербург',
#  'Янино-1',
#  'Парголово',
#  'Мурино',
#  'Ломоносов',
#  'Сертолово',
#  'Петергоф',
#  'Пушкин',
#  'Кудрово',
#  'Коммунар',
#  'Колпино',
#  'Красный Бор',
#  'Гатчина',
#  'Федоровское',
#  'Выборг',
#  'Кронштадт',
#  'Кировск',
#  'Новое Девяткино',
#  'Металлострой',
#  'Сиверский',
#  'Молодцово',
#  'Кузьмоловский',
#  'Павловск',
#  'Пикколово',
#  'Всеволожск',
#  'Кингисепп',
#  'Сестрорецк',
#  'Куттузи',
#  'Ефимовский',
#  'Плодовое',
#  'Заклинье',
#  'Торковичи',
#  'Красное Село',
#  'Понтонный',
#  'Сясьстрой',
#  'Новый Свет',
#  'Приозерск',
#  'Сланцы',
#  'Путилово',
#  'Ивангород',
#  'Шлиссельбург',
#  'Никольское',
#  'Зеленогорск',
#  'Сосновый Бор',
#  'Оржицы',
#  'Кальтино',
#  'Романовка',
#  'Бугры',
#  'Рощино',
#  'Луга',
#  'Волосово',
#  'Отрадное',
#  'Павлово',
#  'Оредеж',
#  'Копорье',
#  'Тихвин',
#  'Нурма',
#  'Синявино',
#  'Тосно',
#  'Стрельна',
#  'Александровская',
#  'Лопухинка',
#  'Пикалево',
# ...

# %% [markdown]
# Хоть и не самым изящным способом, но удалось сократить количество уникальных значений в столбце `location_name` с 331 до 281.

# %% [markdown]
# **Посмотрим столбец `is_apartment`.**
#
# Ранее в нем было выявлено значительное количество пропусков.

# %%
# Посмотрим % пропусков в столбце.
data['is_apartment'].isna().sum()/data.shape[0]*100
# Out:
# 87.86028334147534

# %% [markdown]
# 88% пропусков - это очень много. Попробуем разобраться.

# %%
# Посмотрим не пропущенные значения в столбце.
data['is_apartment'].value_counts()
# Out:
# False    2447
# True       38
# Name: is_apartment, dtype: int64

# %% [markdown]
# Столбец апартаменты, видимо, это не обязательная опция при создании объявления о продаже, если продается иной тип недвижимости - данная опция игнорируется пользователями. Все пропущенные значения заменим на False.

# %%
# Заменяем пропущенные значения на False.
data['is_apartment'] = data['is_apartment'].fillna(False)
# Проверим результат замены.
data['is_apartment'].value_counts()
# Out:
# False    20432
# True        38
# Name: is_apartment, dtype: int64

# %% [markdown]
# После обработки пропуски не обнаружены.

# %% [markdown]
# **Посмотрим столбец `is_studio`.**
#
# В предварительном анализе в столбце пропусков и аномалий обнаружено не было, но все-таки посмотрим.

# %%
# Рассмотрим значения в столбце.
data['is_studio'].value_counts()
# Out:
# False    20335
# True       135
# Name: is_studio, dtype: int64

# %% [markdown]
# Данные в столбце не требуют предобработки.

# %% [markdown]
# **Посмотрим столбец `is_open_plan`.**
#
# В предварительном анализе в столбце пропусков и аномалий обнаружено не было, но все-таки посмотрим.

# %%
# Рассмотрим значения в столбце.
data['is_open_plan'].value_counts()
# Out:
# False    20403
# True        67
# Name: is_open_plan, dtype: int64

# %% [markdown]
# Данные в столбце не требуют предобработки.

# %% [markdown]
# **Посмотрим столбец `total_floors_in_house`.**
#
# В предварительном анализе в столбце были обнаружены пропуски.

# %%
# Посмотрим количество пропусков.
data['total_floors_in_house'].isna().sum()
# Out:
# 76

# %%
# Посмотрим % пропусков.
data['total_floors_in_house'].isna().sum()/data.shape[0]*100
# Out:
# 0.37127503663898387

# %%
# Посмотрим несколько строк с пропусками.
data[data['total_floors_in_house'].isna()].head()
# Out:
#       total_images first_day_exposition  days_exposition  last_price  \
# 155             12           2018-10-02               49    11640000
# 195              4           2016-11-23              251     2438033
# 386              4           2015-08-01              727     9788348
# 575              4           2017-04-06              123     6051191
# 1518             5           2017-04-22               77     3600000
#
#         location_name  is_apartment  is_studio  is_open_plan  \
# 155   Санкт-Петербург         False      False         False
# 195   Санкт-Петербург         False      False         False
# 386   Санкт-Петербург         False      False         False
# 575   Санкт-Петербург         False      False         False
# 1518  Санкт-Петербург         False      False         False
#
#       total_floors_in_house  floor  ...  total_area_m2  living_area_m2  \
# 155                     NaN      4  ...           65.2           30.80
# ...

# %% [markdown]
# % пропусков не большой. Больше похоже на ошибку экспорта данных, но может быть и недостаток данных в БД по конкретным домам.
#
# Плохо могу себе представить ситуацию когда выставляется кваритра в доме с неизвестной этажностью.
#
# Для исследования нам этажность дома не требуется. Возможно пропуски имеет смысл оставить.

# %% [markdown]
# **Посмотрим столбец `floor`.**
#
# В предварительном анализе в столбце пропусков и аномалий обнаружено не было, но все-таки посмотрим.

# %%
# Рассмотрим значения в столбце.
data['floor'].value_counts()
# Out:
# 2     2852
# 3     2642
# 1     2465
# 4     2384
# 5     2240
# 6     1140
# 7     1052
# 9      944
# 8      939
# 10     606
# 12     484
# 11     462
# 13     348
# 15     298
# 14     294
# 16     281
# 17     207
# 18     159
# 19     132
# 21     113
# 20     105
# 22      96
# 23      89
# 24      57
# 25      45
# 26      22
# 27      10
# 33       1
# 28       1
# 32       1
# 31       1
# Name: floor, dtype: int64

# %% [markdown]
# Со столбцом все в порядке, вносить изменения не требуется.

# %% [markdown]
# **Посмотрим столбец `number_of_rooms`.**
#
# В предварительном анализе в столбце пропусков и аномалий обнаружено не было, но все-таки посмотрим.

# %%
# Рассмотрим значения в столбце.
data['number_of_rooms'].value_counts()
# Out:
# 1     7262
# 2     6897
# 3     4803
# 4      936
# 5      252
# 0      183
# 6       76
# 7       37
# 8       11
# 9        4
# 14       2
# 10       2
# 19       1
# 11       1
# 12       1
# 16       1
# 15       1
# Name: number_of_rooms, dtype: int64

# %% [markdown]
# Немного странно выглядят строки с 0 комнат, но возможно это некое помещение(склад, магазин, гараж и т.д.). Количество таких строк незначительно, думаю, что можно оставить как есть.

# %% [markdown]
# **Посмотрим столбец `number_of_balconies`.**
#
# Ранее были выявлены пропуски в столбце. Рассмотрим столбец подробнее.

# %%
# Посмотрим количество пропусков.
data['number_of_balconies'].isna().sum()
# Out:
# 9404

# %%
# Посмотрим % пропусков.
data['number_of_balconies'].isna().sum()/data.shape[0]*100
# Out:
# 45.94040058622374

# %%
# Рассмотрим значения в столбце.
data['number_of_balconies'].value_counts()
# Out:
# 0.0    3725
# 1.0    3649
# 2.0    3234
# 5.0     243
# 4.0     148
# 3.0      67
# Name: number_of_balconies, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Круто, что ты такж детально анализируешь каждый параметр.
#
# </div>

# %% [markdown]
# Очень много пропусков. Скорее всего данные о количестве балконов заполняется вручную и пропуски связаны с тем что при заполнении анкеты, если нет балкона, этот пункт многие просто пропускают. Заполним пропуски нулями и приведем столбец к формату int.

# %%
# Заменим пропуски в number_of_balconies и заменим тип данных.
data['number_of_balconies'] = data['number_of_balconies'].fillna(0).astype('int')

# %%
# Проверим количество пропусков после заполнения пропусков.
data['number_of_balconies'].isna().sum()
# Out:
# 0

# %%
# Проверим изменение формата столбца.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20470 entries, 0 to 20469
# Data columns (total 22 columns):
# total_images               20470 non-null int64
# first_day_exposition       20470 non-null datetime64[ns]
# days_exposition            20470 non-null int64
# last_price                 20470 non-null int64
# location_name              20470 non-null object
# is_apartment               20470 non-null bool
# is_studio                  20470 non-null bool
# is_open_plan               20470 non-null bool
# total_floors_in_house      20394 non-null float64
# floor                      20470 non-null int64
# number_of_rooms            20470 non-null int64
# number_of_balconies        20470 non-null int64
# total_area_m2              20470 non-null float64
# living_area_m2             18770 non-null float64
# kitchen_area_m2            18404 non-null float64
# ceiling_height_m           12037 non-null float64
# city_center_m              15824 non-null float64
# ...

# %% [markdown]
# Пропуски заполнены, формат столбца изменен.

# %% [markdown]
# **Посмотрим столбец `total_area_m2`.**
#
# В предварительном анализе в столбце пропусков и аномалий обнаружено не было, но все-таки посмотрим.

# %%
# Рассмотрим значения в столбце.
data['total_area_m2'].value_counts()
# Out:
# 45.00     385
# 42.00     339
# 31.00     319
# 44.00     311
# 60.00     308
#          ...
# 101.10      1
# 35.69       1
# 185.80      1
# 58.54       1
# 23.55       1
# Name: total_area_m2, Length: 2021, dtype: int64

# %% [markdown]
# Со столбцом все в порядке, вносить изменения не требуется.

# %% [markdown]
# **Посмотрим столбец `living_area_m2`.**
#
# Ранее были выявлены пропуски в столбце. Рассмотрим столбец подробнее.

# %%
# Посмотрим количество пропусков.
data['living_area_m2'].isna().sum()
# Out:
# 1700

# %%
# Посмотрим % пропусков.
data['living_area_m2'].isna().sum()/data.shape[0]*100
# Out:
# 8.304836345872008

# %%
# Посмотрим статистику по столбцу
data['living_area_m2'].describe()
# Out:
# count    18770.000000
# mean        33.525704
# std         21.323309
# min          2.000000
# 25%         18.300000
# 50%         30.000000
# 75%         41.575000
# max        409.700000
# Name: living_area_m2, dtype: float64

# %% [markdown]
# Пропусков достаточно много. Скорее всего данные о жилой площади заполняются вручную, этим и обусловлены пропуски.
# ~~Можно конечно посчитать средний процент жилой площади от всей площади по всей выборке и высчитать для строк с пропусками жилую площадь, но не уверен что это как-то улучшит изучаемые данные. Может же быть изба 1000м с кухней 10м и жилой площадью 990м, а может быть квартира 35м с кухней 8м и жилой площадью 27м например. Оставим как есть.~~ Посмотрим есть ли корреляция между общей площадью и жилой.

# %%
# Посмотрим корреляцию между общей площадью и жилой.
living_area_corr = data['total_area_m2'].corr(data['living_area_m2'])
living_area_corr
# Out:
# 0.9390532539537833

# %% [markdown]
# Получили большое значение корреляции. Посчитаем медианную разницу(чтобы обросить аномальные значения)между общей и жилой площадью. Запишем это значение в переменную и заполним пропуски в столбце с жилой площадью.

# %%
# Добавим вспомогательный столбец в датафрейм с отношением жилой площади к общей.
data['total_living_area_ratio'] = data['living_area_m2'] / data['total_area_m2']
# Создадим переменную в которую сохраним медиану отношения жилой площади к общей.
living_area_median = data['total_living_area_ratio'].median()
living_area_median
# Out:
# 0.5652547437621396

# %% [markdown]
# Медиана отношения жилой площади к общей равна примерно 56%.

# %%
# Заполним пропуски с помощью полученного ранее значения.
data['living_area_m2'] = data['living_area_m2'].fillna(data['total_area_m2'] * living_area_median).round(1)

# %%
# Проверим не осталось ли пропусков.
data['living_area_m2'].isna().sum()
# Out:
# 0

# %%
# Проверим количество пропусков
data['total_living_area_ratio'].isna().sum()
# Out:
# 1700

# %%
# Заполним пропущенные значения
data['total_living_area_ratio'] = data['total_living_area_ratio'].fillna(data['living_area_m2'] / data['total_area_m2'])

# %%
# Проверим количество пропусков
data['total_living_area_ratio'].isna().sum()
# Out:
# 0

# %%
# Посмотрим статистику по столбцу
data['living_area_m2'].describe()
# Out:
# count    20470.000000
# mean        33.593664
# std         21.364784
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         41.200000
# max        409.700000
# Name: living_area_m2, dtype: float64

# %% [markdown]
# Пропуски в столбце с жилой площадью заполнили.

# %% [markdown]
# **Посмотрим столбец `kitchen_area_m2`.**
#
# Ранее были выявлены пропуски в столбце. Рассмотрим столбец подробнее.

# %%
# Посмотрим количество пропусков.
data['kitchen_area_m2'].isna().sum()
# Out:
# 2066

# %%
# Посмотрим % пропусков.
data['kitchen_area_m2'].isna().sum()/data.shape[0]*100
# Out:
# 10.092818759159746

# %%
# Посмотрим статистику по столбцу
data['kitchen_area_m2'].describe()
# Out:
# count    18404.000000
# mean        10.432382
# std          5.677438
# min          2.000000
# 25%          7.000000
# 50%          9.100000
# 75%         11.922500
# max        112.000000
# Name: kitchen_area_m2, dtype: float64

# %% [markdown]
# Ситуация такая же как и со столбцом `living_area_m2`. ~~Оставим как есть.~~ Посмотрим есть ли корреляция между общей площадью и площадью кухни.

# %%
# Посмотрим корреляцию между общей площадью и площадью кухни.
kitchen_area_corr = data['total_area_m2'].corr(data['kitchen_area_m2'])
kitchen_area_corr
# Out:
# 0.6105898607212331

# %% [markdown]
# Получили большое значение корреляции. Не такое большое как в случае с жилой площадью и общей, но все-равно значительную. Посчитаем медианную разницу(чтобы обросить аномальные значения)между общей площадью и площадью кухни. Запишем это значение в переменную и заполним пропуски в столбце с площадью кухни.

# %%
# Добавим вспомогательный столбец в датафрейм с отношением площади кухни к общей.
data['total_kitchen_area_ratio'] = data['kitchen_area_m2'] / data['total_area_m2']
# Создадим переменную в которую сохраним медиану отношения площади кухни к общей.
kitchen_area_median = data['total_kitchen_area_ratio'].median()
kitchen_area_median
# Out:
# 0.175

# %% [markdown]
# Медиана отношения жилой площади к общей равна примерно 17%.

# %%
# Заполним пропуски с помощью полученного ранее значения.
data['kitchen_area_m2'] = data['kitchen_area_m2'].fillna(data['total_area_m2'] * kitchen_area_median).round(1)

# %%
# Проверим не осталось ли пропусков.
data['kitchen_area_m2'].isna().sum()
# Out:
# 0

# %%
# Проверим количество пропусков
data['total_kitchen_area_ratio'].isna().sum()
# Out:
# 2066

# %%
# Заполним пропущенные значения
data['total_kitchen_area_ratio'] = data['total_kitchen_area_ratio'].fillna(data['kitchen_area_m2'] / data['total_area_m2'])

# %%
# Проверим количество пропусков
data['total_kitchen_area_ratio'].isna().sum()
# Out:
# 0

# %%
# Посмотрим статистику по столбцу
data['kitchen_area_m2'].describe()
# Out:
# count    20470.000000
# mean        10.347943
# std          5.786425
# min          2.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.800000
# max        112.000000
# Name: kitchen_area_m2, dtype: float64

# %% [markdown]
# Пропуски в столбце с площадью кухни заполнили.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: Пропуски в площади кухни и жилого пространства также стоит обработать. Существует достаточное число способов для их заполнения. Попробуй это реализовать. Подумай, от чего зависят данные параметры. Можно взглянуть, например, на корреляции данных площадей и других параметров квартиры для нахождения наиболее сильной зависимости.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Хоть в дальнейшем исследовании нам эти данные не понадобятся - заполнил пропуски в столбцах с площадью кухни и жилой площадью.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: На этих данных мы рассчитываем доли каждого помещения для всех объявлений. Поэтому сказать, что данные параметры не задействованы далее мы не можем. Обработать эти пропуски мы можем, что и сделал. Классная реализация.
#
# </div>

# %% [markdown]
# **Посмотрим столбец `ceiling_height_m`.**
#
# Ранее были выявлены пропуски в столбце. Рассмотрим столбец подробнее.

# %%
# Посмотрим количество пропусков.
data['ceiling_height_m'].isna().sum()
# Out:
# 8433

# %%
# Посмотрим % пропусков.
data['ceiling_height_m'].isna().sum()/data.shape[0]*100
# Out:
# 41.196873473375675

# %%
# Посмотрим статистику по столбцу
data['ceiling_height_m'].describe()
# Out:
# count    12037.000000
# mean         2.761539
# std          1.264449
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height_m, dtype: float64

# %% [markdown]
# Очень много пропусков 39%, скорее всего данные заполняются вручную. Есть аномальные значения: 1м - минимальная высота потолка, 100м - максимальная высота потолка. Аномалии и пропуски оставим, вряд ли заполнение пропусков медианными значениями нам поможет в дальнейшем исследовании.

# %% [markdown]
# **Посмотрим столбец `city_center_m`.**
#
# Ранее в столбце были выявлены пропуски.

# %%
# Посмотрим количество пропусков.
data['city_center_m'].isna().sum()
# Out:
# 4646

# %%
# Посмотрим % пропусков.
data['city_center_m'].isna().sum()/data.shape[0]*100
# Out:
# 22.696629213483146

# %% [markdown]
# Видим значительное количество пропусков. Не имея информации о адресе и координатах выславленной недвижимости - невозможно определить расстояние до центра. Оставляем пропуски т.к. заполняя их средними или медианными значениями может ухудшить данные в датафрейме. Будем работать с тем что есть.

# %% [markdown]
# **Посмотрим столбец `nearest_airport_m`.**
#
# Ранее в столбце были выявлены пропуски.

# %%
# Посмотрим количество пропусков.
data['nearest_airport_m'].isna().sum()
# Out:
# 4668

# %%
# Посмотрим % пропусков.
data['nearest_airport_m'].isna().sum()/data.shape[0]*100
# Out:
# 22.80410356619443

# %% [markdown]
# Видим значительное количество пропусков. В дальнейшем исследовании нам данные из столбца не пригодятся. Оставляем все как есть.

# %% [markdown]
# **Посмотрим столбец `nearest_park_m`.**
#
# Ранее в столбце были выявлены пропуски.

# %%
# Посмотрим количество пропусков.
data['nearest_park_m'].isna().sum()
# Out:
# 13551

# %%
# Посмотрим % пропусков.
data['nearest_park_m'].isna().sum()/data.shape[0]*100
# Out:
# 66.19931607230093

# %% [markdown]
# Видим значительное количество пропусков. В дальнейшем исследовании нам данные из столбца не пригодятся. Оставляем все как есть.

# %% [markdown]
# **Посмотрим столбец `parks_number_within_3km`.**
#
# Ранее в столбце были выявлены пропуски.

# %%
# Посмотрим количество пропусков.
data['parks_number_within_3km'].isna().sum()
# Out:
# 4646

# %%
# Посмотрим % пропусков.
data['parks_number_within_3km'].isna().sum()/data.shape[0]*100
# Out:
# 22.696629213483146

# %% [markdown]
# Видим значительное количество пропусков. В дальнейшем исследовании нам данные из столбца не пригодятся. Оставляем все как есть.

# %% [markdown]
# **Посмотрим столбец `nearest_pond_m`.**
#
# Ранее в столбце были выявлены пропуски.

# %%
# Посмотрим количество пропусков.
data['nearest_pond_m'].isna().sum()
# Out:
# 12601

# %%
# Посмотрим % пропусков.
data['nearest_pond_m'].isna().sum()/data.shape[0]*100
# Out:
# 61.558378114313626

# %% [markdown]
# Видим значительное количество пропусков. В дальнейшем исследовании нам данные из столбца не пригодятся. Оставляем все как есть.

# %% [markdown]
# **Посмотрим столбец `ponds_number_within_3km`.**
#
# Ранее в столбце были выявлены пропуски.

# %%
# Посмотрим количество пропусков.
data['ponds_number_within_3km'].isna().sum()
# Out:
# 4646

# %%
# Посмотрим % пропусков.
data['ponds_number_within_3km'].isna().sum()/data.shape[0]*100
# Out:
# 22.696629213483146

# %% [markdown]
# Видим значительное количество пропусков. В дальнейшем исследовании нам данные из столбца не пригодятся. Оставляем все как есть.

# %% [markdown]
# ### Поиск дублей.

# %% [markdown]
# **Проверим есть ли дубли в датафрейме.**

# %%
# Посмотрим количество дублей.
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дублей не обнаружено.

# %% [markdown]
# ### Вывод.

# %% [markdown]
# Посмотрели данные во всех столбцах предоставленного датафрейма.
#
# Обнаружено очень много пропусков, там где это было возможно и необходимо - пропуски были заполнены.
#
# Было бы очень не плохо ввести в датафрейм адреса с привязкой к местности, тогда можно было бы избежать проблем с пропусками в населенных пунктах, в этажности домов, в высоте потолков(очень редко бывает так что в одном и том же доме в квартирах потолки разной высоты), в расстоянии до центра, в расстоянии до аэропорта, в расстоянии до парка, в расстоянии до водоема, в жилой площади и площади кухни(квартиры в домах обычно типовые). Так же хотелось бы видеть столбцы с типом населенного пункта(город, село, поселок и т.д) и типом недвижимости(квартира, дом, участок, гараж, склад и тд.). А так придется работать с тем что есть.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Пропуски обработаны там, где это возможно. Типы данных скорректированы. Данные подготовлены к дальнейшему анализу.
#
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Цена квадратного метра.

# %% [markdown]
# Посчитаем и добавим столбец с ценой квадратного метра.

# %%
# Посчитаем цену квадратного метра.
data['price_per_square_meter'] = data['last_price'] / data['total_area_m2']
# Для удобства просмотра приведем к типу int.
data['price_per_square_meter'] = data['price_per_square_meter'].astype('int')
# Проверим результат.
data.head()
# Out:
#    total_images first_day_exposition  days_exposition  last_price  \
# 0             7           2018-12-04               81     3350000
# 1            10           2015-08-20              558     5196000
# 2             0           2015-07-24              424    64900000
# 3             2           2018-06-19              121    10000000
# 4            10           2018-09-10               55     2890000
#
#      location_name  is_apartment  is_studio  is_open_plan  \
# 0           Шушары         False      False         False
# 1  Санкт-Петербург         False      False         False
# 2  Санкт-Петербург         False      False         False
# 3  Санкт-Петербург         False      False         False
# 4          Янино-1         False      False         False
#
#    total_floors_in_house  floor  ...  ceiling_height_m  city_center_m  \
# 0                   11.0      1  ...               NaN        18603.0
# 1                    5.0      4  ...               NaN        13933.0
# ...

# %% [markdown]
# ### День недели, месяц и год публикации объявления.

# %% [markdown]
# Посчитаем и добавим столбцы с днем недели, месяцем и годом публикации объявления.

# %%
# Создаем столбец дня недели.
data['day_of_week_exposition'] = data['first_day_exposition'].dt.weekday
# Создаем столбец месяца.
data['month_exposition'] = data['first_day_exposition'].dt.month
# Создаем столбец года.
data['year_exposition'] = data['first_day_exposition'].dt.year
# Проверяем результат.
data.head()
# Out:
#    total_images first_day_exposition  days_exposition  last_price  \
# 0             7           2018-12-04               81     3350000
# 1            10           2015-08-20              558     5196000
# 2             0           2015-07-24              424    64900000
# 3             2           2018-06-19              121    10000000
# 4            10           2018-09-10               55     2890000
#
#      location_name  is_apartment  is_studio  is_open_plan  \
# 0           Шушары         False      False         False
# 1  Санкт-Петербург         False      False         False
# 2  Санкт-Петербург         False      False         False
# 3  Санкт-Петербург         False      False         False
# 4          Янино-1         False      False         False
#
#    total_floors_in_house  floor  ...  nearest_park_m  parks_number_within_3km  \
# 0                   11.0      1  ...             NaN                      0.0
# ...

# %% [markdown]
# ### Категоризация по этажам.

# %% [markdown]
# Добавим столбец `floor_category` с категориями по этажам.

# %%
# Функция категоризации по этажам.
def floor_category(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['total_floors_in_house']:
        return 'последний'
    else:
        return 'другой'

# %%
# Добавление результатов работы функции в новый столбец.
data['floor_category'] = data.apply(floor_category, axis=1)
# Проверим результат.
data.head()
# Out:
#    total_images first_day_exposition  days_exposition  last_price  \
# 0             7           2018-12-04               81     3350000
# 1            10           2015-08-20              558     5196000
# 2             0           2015-07-24              424    64900000
# 3             2           2018-06-19              121    10000000
# 4            10           2018-09-10               55     2890000
#
#      location_name  is_apartment  is_studio  is_open_plan  \
# 0           Шушары         False      False         False
# 1  Санкт-Петербург         False      False         False
# 2  Санкт-Петербург         False      False         False
# 3  Санкт-Петербург         False      False         False
# 4          Янино-1         False      False         False
#
#    total_floors_in_house  floor  ...  parks_number_within_3km  nearest_pond_m  \
# 0                   11.0      1  ...                      0.0             NaN
# ...

# %% [markdown]
# ### Соотношение площадей.

# %% [markdown]
# ~~Посчитаем и добавим в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей.~~
# Соотношение площадей посчитали при заполнении пропусков с столбцах `living_area_m2`и `kitchen_area_m2`.

# %%
# Создадим столбец с соотношением жилой и общей площади.
# data['total_living_area_ratio'] = data['living_area_m2'] / data['total_area_m2']
# Создадим столбец с соотношением площади кухни к общей.
# data['total_kitchen_area_ratio'] = data['kitchen_area_m2'] / data['total_area_m2']
# Проверим результат.
data.head()
# Out:
#    total_images first_day_exposition  days_exposition  last_price  \
# 0             7           2018-12-04               81     3350000
# 1            10           2015-08-20              558     5196000
# 2             0           2015-07-24              424    64900000
# 3             2           2018-06-19              121    10000000
# 4            10           2018-09-10               55     2890000
#
#      location_name  is_apartment  is_studio  is_open_plan  \
# 0           Шушары         False      False         False
# 1  Санкт-Петербург         False      False         False
# 2  Санкт-Петербург         False      False         False
# 3  Санкт-Петербург         False      False         False
# 4          Янино-1         False      False         False
#
#    total_floors_in_house  floor  ...  parks_number_within_3km  nearest_pond_m  \
# 0                   11.0      1  ...                      0.0             NaN
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Добавление необходимых для дальнейшего исследования параметров произведено.
#
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучаем следующие параметры: площадь, цена, число комнат, высота потолков.

# %% [markdown]
# **Изучим площадь.**

# %%
# Выведем данные по столбцу с общей площадью.
data['total_area_m2'].describe()
# Out:
# count    20470.000000
# mean        58.845355
# std         34.080771
# min         12.000000
# 25%         39.500000
# 50%         50.800000
# 75%         67.800000
# max        900.000000
# Name: total_area_m2, dtype: float64

# %% [markdown]
# Напишем функцию которая будет возвращать границу "усов" для задаваемого признака. Будем использовать ее при построении границ графиков.

# %%
# функция, получающая на вход название признака, и возвращающая границы "усов"
def mustache_range(df, column):
    statistic = df[column].describe() 
    # межквартирльный размах
    iqr = statistic[6] - statistic[4]
    # левый и правый "ус"    
    left_mustache = round(statistic[4] - 3 * iqr, 2)
    right_mustache = round(statistic[6] + 3 * iqr, 2)
    # левый "ус" не должен быть меньше минимального значения
    if left_mustache < statistic[3]:
        left_mustache = statistic[3] 
    # правый "ус" не должен быть больше максимального значения
    if right_mustache > statistic[7]:
        right_mustache = statistic[7]
        
    return [left_mustache, right_mustache]

# %%
# Посмотрим границу "усов".
mustache_range(data, 'total_area_m2')
# Out:
# [12.0, 152.7]

# %%
# Построим гистограмму по данным в столбце.
data.plot(y = 'total_area_m2', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (mustache_range(data, 'total_area_m2')))
plt.title('Площади квартир', size=14)
plt.xlabel('Площадь, м²')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %% [markdown]
# Общая площадь в нашей выборке колеблется от 12 до 900 кв.м, среднее значение 60 кв.м, а медиана 52 кв.м
# Средние значения и медианы выглядят нормально. Есть аномалии, но они не сильно влияют на общие данные.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: Не забывай подписывать оси на графиках и делать им названия. Это все же также важные элементы любой визуализации. Как делать подписи и названия, смотри [тут](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [тут](https://pyprog.pro/mpl/mpl_title.html).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Поправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Не забывай про данные важные элементы любой визуализации.
#
# </div>

# %% [markdown]
# **Изучим цену.**

# %%
# Выведем данные по столбцу с ценой недвижимости. Для читаемости данных применим apply("{}}".format).
data['last_price'].describe().apply("{0:.2f}".format)
# Out:
# count        20470.00
# mean       6264805.30
# std       10873552.34
# min          12190.00
# 25%        3400000.00
# 50%        4500000.00
# 75%        6500000.00
# max      763000000.00
# Name: last_price, dtype: object

# %%
# Посмотрим границу "усов".
mustache_range(data, 'last_price')
# Out:
# [12190.0, 15800000.0]

# %%
# Построим гистограмму по данным в столбце.
data.plot(y = 'last_price', kind = 'hist', bins = 100, grid=True, range = (mustache_range(data, 'last_price')), figsize = (10,5))
plt.title('Цена квартир', size=14)
plt.xlabel('Цена, млн.руб')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %% [markdown]
# Цены на недвижимость имеют среднее значение в 6,3 млн руб., медиана 4,5 млн руб.
# Аномально выглядят цены в 12 тыс.руб и в 763 млн. руб., но может это цена за сарай и особняк. В общем каждый может найти вариант для себя.

# %% [markdown]
# **Изучим число комнат.**

# %%
# Выведем данные по столбцу с количеством комнат.
data['number_of_rooms'].describe()
# Out:
# count    20470.000000
# mean         2.023889
# std          1.054972
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: number_of_rooms, dtype: float64

# %%
# Посмотрим еще раз значения в столбце.
data['number_of_rooms'].value_counts()
# Out:
# 1     7262
# 2     6897
# 3     4803
# 4      936
# 5      252
# 0      183
# 6       76
# 7       37
# 8       11
# 9        4
# 14       2
# 10       2
# 19       1
# 11       1
# 12       1
# 16       1
# 15       1
# Name: number_of_rooms, dtype: int64

# %%
# Посмотрим границу "усов".
mustache_range(data, 'number_of_rooms')
# Out:
# [0.0, 9.0]

# %%
# Построим гистограмму по данным в столбце.
data.plot(y = 'number_of_rooms', kind = 'hist', bins = 50, grid=True, figsize = (10,5), range = (mustache_range(data, 'number_of_rooms')))
plt.title('Количество комнат', size=14)
plt.xlabel('Количество комнат, шт')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %% [markdown]
# Количество комнат колеблется от 0 до 19. Больше всего однокомнатных и двукомнатных квартир.
# Аномальными кажутся квартиры с 0 комнат(возможно студии или нежилые помещения).

# %% [markdown]
# **Изучим высоту потолков.**

# %%
# Выведем данные по столбцу с высотой потолков.
data['ceiling_height_m'].describe()
# Out:
# count    12037.000000
# mean         2.761539
# std          1.264449
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height_m, dtype: float64

# %%
# Посмотрим еще раз значения в столбце.
data['ceiling_height_m'].value_counts()
# Out:
# 2.50      2888
# 2.60      1410
# 2.70      1348
# 3.00       870
# 2.55       844
#           ...
# 22.60        1
# 3.59         1
# 4.80         1
# 26.00        1
# 100.00       1
# Name: ceiling_height_m, Length: 176, dtype: int64

# %%
# Посмотрим границу "усов".
mustache_range(data, 'ceiling_height_m')
# Out:
# [1.68, 3.64]

# %%
# Построим гистограмму по данным в столбце.
data.plot(y = 'ceiling_height_m', kind = 'hist', bins = 50, grid=True, range = (mustache_range(data, 'ceiling_height_m')), figsize = (10,5))
plt.title('Высота потолков', size=14)
plt.xlabel('Высота потолка, м')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %% [markdown]
# Средняя высота потолка 2,76 м, медианная 2,65 м. Выявлены аномальные значения, например: высота потолка 1 м или высота потолка 100 м.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: При анализе ты проводишь однотипные действия на каждом шаге. Попробуй автоматизировать процесс построения графиков через цикл или собственную функцию. Интервал построения графиков рассчитывай автоматически. Например, от Q1-3\*IQR до Q3+3\*IQR.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Написал функцию для расчета интервала для графиков.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Очень крутая функция получилась. Здорово, что ты ее реализовал.
#
# </div>

# %% [markdown]
# ### Изучение времени продажи квартир.

# %% [markdown]
# Требуется изучить время продажи квартиры. Построить гистограмму. Посчитать среднее и медиану. Описать, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
# Посмотрим статистику по столбцу days_exposition.
# Cреднее значение, медиана и межквартильный размах.
data['days_exposition'].describe()
# Out:
# count    20470.000000
# mean       180.753200
# std        219.777916
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
mustache_range(data, 'days_exposition')
# Out:
# [1.0, 789.0]

# %%
# Построим диаграмму размаха.
# Учтем что пустые значения(действующие объявления) мы заполнили нулями.
plt.figure(figsize=(10, 10))
plt.ylim(mustache_range(data, 'days_exposition'))
plt.boxplot(data['days_exposition'])
plt.title('Время продажи квартир', size=14)
plt.ylabel('Время продажи квартир, дни')
# Out:
# Text(0, 0.5, 'Время продажи квартир, дни')

# %%
# Построим гистограмму.
data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (mustache_range(data, 'days_exposition')), figsize = (10,5))
plt.title('Время продажи квартир', size=14)
plt.xlabel('Время продажи квартир, дни')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %%
# Посмотрим 15 чаще всего встречающихся значений в столбце.
# Учтем что пустые значения(действующие объявления) мы заполнили нулями.
data['days_exposition'].value_counts().head(15)
# Out:
# 45    879
# 60    538
# 7     234
# 30    208
# 90    203
# 4     174
# 3     158
# 5     152
# 14    148
# 9     142
# 8     139
# 20    139
# 44    138
# 11    135
# 18    129
# Name: days_exposition, dtype: int64

# %% [markdown]
# Среднее время с момента размещения объявления 180 дней, медианное 95 дней.
#
# Большую часть объявлений снимают с размещения в период от 45 до 231 дня. Если смотреть на диаграмму размаха нижний "ус" находится в районе 1 дня, а верхний "ус" находится в районе 500 дней. Значит необоснованно быстрых значений в датафрейме нет, а необоснованно долгие - от 500 дней и выше. Значит нормальные значения у нас лежат от 1 до 500 дней.
#
# На гистограмме были выявлены аномальные всплески, судя по чаще всего встречающимся значениям они приходятся на 45, 60, 30 и 90 дней. Судя по данным Яндекс Недвижимость(https://yandex.ru/support/realty/paid.html) - это сроки публикаций объявлений перед их автоматическим снятием(по крайней мере цифры совпадают). Сейчас видно что для Санкт-Петербурга и области правила другие, но не известно было ли так всегда. Нужно будет уточнить у коллег, которые готовили данные, по поводу этих значений т.к. в датафрейме информации о автоматическом снятии объявлений нет. Пока будем считать их аномальными.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Здорово, что есть гипотезы о быстрых и долгих сделках.
#
# </div>

# %% [markdown]
# ### Уберем редкие и выбивающиеся значения.

# %% [markdown]
# **Уберем редкие и выбивающиеся значения. Опишем, какие особенности обнаружили.**

# %%
# Создадим новый датафрейм для записи данных без аномалий.
good_data = data.query('days_exposition != 45 and days_exposition != 30 and days_exposition != 60 and days_exposition != 90')

# %%
# Напишем процедуру для обрезки выборки по заданному квантилю.
def mustache_cut(df, column):
    q1 = df[column].quantile(0.05)
    q3 = df[column].quantile(0.95)
    iqr = q3 - q1
    left_mustache = round(q1 - 1.5 * iqr, 2)
    right_mustache = round(q3 + 1.5 * iqr, 2)
    if left_mustache < df[column].min():
        left_mustache = df[column].min()
    if right_mustache > df[column].max():
        right_mustache = df[column].max()
    return df[(df[column] > left_mustache) & (df[column] < right_mustache)]

# %%
# Посмотрим статистику по столбцу days_exposition в новом датафрейме.
good_data['days_exposition'].describe()
# Out:
# count    18642.000000
# mean       193.309355
# std        226.380754
# min          1.000000
# 25%         43.000000
# 50%        112.000000
# 75%        255.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
# Построим диаграмму размаха.
plt.figure(figsize=(10, 10))
plt.ylim(mustache_range(good_data, 'days_exposition'))
plt.boxplot(good_data['days_exposition'])
plt.title('Время продажи квартир', size=14)
plt.ylabel('Время продажи квартир, дни')
# Out:
# Text(0, 0.5, 'Время продажи квартир, дни')

# %%
# Построим гистограмму по новому датафрейму.
good_data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (mustache_range(good_data, 'days_exposition')), figsize = (10,5))
plt.title('Время продажи квартир', size=14)
plt.xlabel('Время продажи квартир, дни')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %%
# Выполним процедуру для обрезки выбивающихся значений.
good_data = mustache_cut(good_data, 'days_exposition')

# %%
# Обрежем выбросы по квартилям.
#q1 = good_data['days_exposition'].quantile(0.25)                 
#q3 = good_data['days_exposition'].quantile(0.75)
#iqr = q3-q1
#good_data = good_data[(good_data['days_exposition'] > q1-6*iqr ) & (good_data['days_exposition'] < q3+6*iqr)]

# %%
# Посмотрим статистику по столбцу
good_data['days_exposition'].describe()
# Out:
# count    18640.000000
# mean       193.245279
# std        226.160542
# min          2.000000
# 25%         43.000000
# 50%        112.000000
# 75%        255.000000
# max       1572.000000
# Name: days_exposition, dtype: float64

# %%
# Построим диаграмму размаха.
plt.figure(figsize=(10, 10))
plt.ylim(mustache_range(good_data, 'days_exposition'))
plt.boxplot(good_data['days_exposition'])
plt.title('Время продажи квартир', size=14)
plt.ylabel('Время продажи квартир, дни')
# Out:
# Text(0, 0.5, 'Время продажи квартир, дни')

# %%
# Построим гистограмму по новому датафрейму.
good_data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (mustache_range(good_data, 'days_exposition')), figsize = (10,5))
plt.title('Время продажи квартир', size=14)
plt.xlabel('Время продажи квартир, дни')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %% [markdown]
# После обрезки выбросов в столбце `days_exposition` по квартилям - осталось 18640 строк. Как видим по гистограммам основной массив данных не изменился.
#
# Ранее были обнаружены аномально большие и маленькие значения в столбцах `price_per_square_meter`.Попробуем пока обрезать выбросы по данному столбцу.

# %%
# Посмотрим статистику по столбцу price_per_square_meter в новом датафрейме
good_data['price_per_square_meter'].describe().apply("{0:.2f}".format)
# Out:
# count      18640.00
# mean       98480.40
# std        47664.88
# min          111.00
# 25%        77000.00
# 50%        94270.00
# 75%       112437.00
# max      1907500.00
# Name: price_per_square_meter, dtype: object

# %%
# Построим диаграмму размаха.
plt.figure(figsize=(10, 10))
plt.ylim(mustache_range(good_data, 'price_per_square_meter'))
plt.boxplot(good_data['price_per_square_meter'])
plt.title('Стоимость квадратного метра', size=14)
plt.ylabel('Цена за квадрат, руб')
# Out:
# Text(0, 0.5, 'Цена за квадрат, руб')

# %%
# Построим гистограмму по новому датафрейму.
good_data.plot(y = 'price_per_square_meter', kind = 'hist', bins = 100, grid = True, range = (mustache_range(good_data, 'price_per_square_meter')), figsize = (10,5))
plt.title('Стоимость квадратного метра', size=14)
plt.xlabel('Цена за квадрат, руб')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %%
# Обрежем выбросы по квантилям.
# q1 = good_data['price_per_square_meter'].quantile(0.25)                 
# q3 = good_data['price_per_square_meter'].quantile(0.75)
# iqr = q3-q1
# good_data = good_data[(good_data['price_per_square_meter'] > q1-6*iqr ) & (good_data['price_per_square_meter'] < q3+6*iqr)]

# %%
# Выполним процедуру для обрезки выбивающихся значений.
good_data = mustache_cut(good_data, 'price_per_square_meter')

# %%
# Посмотрим статистику по столбцу.
good_data['price_per_square_meter'].describe().apply("{0:.2f}".format)
# Out:
# count     18542.00
# mean      96457.65
# std       34824.96
# min        7962.00
# 25%       76923.00
# 50%       94117.00
# 75%      112000.00
# max      321739.00
# Name: price_per_square_meter, dtype: object

# %%
# Построим диаграмму размаха.
plt.figure(figsize=(10, 10))
plt.ylim(mustache_range(good_data, 'price_per_square_meter'))
plt.boxplot(good_data['price_per_square_meter'])
plt.title('Стоимость квадратного метра', size=14)
plt.ylabel('Цена за квадрат, руб')
# Out:
# Text(0, 0.5, 'Цена за квадрат, руб')

# %%
# Построим гистограмму по новому датафрейму.
good_data.plot(y = 'price_per_square_meter', kind = 'hist', bins = 100, grid = True , range = (mustache_range(good_data, 'price_per_square_meter')), figsize = (10,5))
plt.title('Стоимость квадратного метра', size=14)
plt.xlabel('Цена за квадрат, руб')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %% [markdown]
# Образали сверхдорогие и сверхдешевые предложения недвижимости. Судя по гистограммам - основной массив данных не задели.

# %% [markdown]
# Ранее были обнаружены аномально большие и маленькие значения в столбцах `total_area_m2`.Попробуем пока обрезать выбросы по данному столбцу.

# %%
# Посмотрим статистику по столбцу `total_area_m2`.
good_data['total_area_m2'].describe()
# Out:
# count    18542.000000
# mean        58.415749
# std         32.217319
# min         12.000000
# 25%         39.400000
# 50%         50.700000
# 75%         67.700000
# max        590.000000
# Name: total_area_m2, dtype: float64

# %%
# Построим диаграмму размаха.
plt.figure(figsize=(10, 10))
plt.ylim(mustache_range(good_data, 'total_area_m2'))
plt.boxplot(good_data['total_area_m2'])
plt.title('Метраж квартир', size=14)
plt.ylabel('Кв.м.')
# Out:
# Text(0, 0.5, 'Кв.м.')

# %%
# Построим гистограмму по новому датафрейму.
good_data.plot(y = 'total_area_m2', kind = 'hist', bins = 100, grid = True, range = (mustache_range(good_data, 'total_area_m2')), figsize = (10,5))
plt.title('Метраж квартир', size=14)
plt.xlabel('Кв.м.')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %%
# Обрежем выбросы по квантилям.
# q1 = good_data['total_area_m2'].quantile(0.25)                 
# q3 = good_data['total_area_m2'].quantile(0.75)
# iqr = q3-q1
# good_data = good_data[(good_data['total_area_m2'] > q1-6*iqr ) & (good_data['total_area_m2'] < q3+6*iqr)]

# %%
# Выполним процедуру для обрезки выбивающихся значений.
good_data = mustache_cut(good_data, 'total_area_m2')

# %%
# Посмотрим статистику по столбцу.
good_data['total_area_m2'].describe()
# Out:
# count    18446.000000
# mean        57.136620
# std         26.221925
# min         13.000000
# 25%         39.200000
# 50%         50.400000
# 75%         67.200000
# max        226.000000
# Name: total_area_m2, dtype: float64

# %%
# Построим диаграмму размаха.
plt.figure(figsize=(10, 10))
plt.ylim(mustache_range(good_data, 'total_area_m2'))
plt.boxplot(good_data['total_area_m2'])
plt.title('Метраж квартир', size=14)
plt.ylabel('Кв.м.')
# Out:
# Text(0, 0.5, 'Кв.м.')

# %%
# Построим гистограмму по новому датафрейму.
good_data.plot(y = 'total_area_m2', kind = 'hist', bins = 100, grid = True, range = (mustache_range(good_data, 'total_area_m2')), figsize = (10,5))
plt.title('Метраж квартир', size=14)
plt.xlabel('Кв.м.')
plt.ylabel('Количество квартир, шт.')
# Out:
# Text(0, 0.5, 'Количество квартир, шт.')

# %%
# Перестроим индексы в новой таблице.
good_data = good_data.reset_index(drop=True)

# %% [markdown]
# Образали сверхдорогие и сверхдешевые предложения недвижимости. Судя по гистограммам - основной массив данных не задели.

# %%
# Посмотрим статистику по столбцам после обрезки.
good_data.describe()
# Out:
#        total_images  days_exposition    last_price  total_floors_in_house  \
# count  18446.000000     18446.000000  1.844600e+04           18374.000000
# mean       9.714084       191.816925  5.669559e+06              10.889518
# std        5.626565       224.471156  4.335457e+06               6.631410
# min        0.000000         2.000000  4.300000e+05               1.000000
# 25%        6.000000        43.000000  3.400000e+06               5.000000
# 50%        9.000000       111.000000  4.500000e+06               9.000000
# 75%       14.000000       252.000000  6.450000e+06              16.000000
# max       50.000000      1553.000000  6.800000e+07              60.000000
#
#               floor  number_of_rooms  number_of_balconies  total_area_m2  \
# count  18446.000000     18446.000000         18446.000000   18446.000000
# mean       5.991380         1.999566             0.595197      57.136620
# std        4.941499         0.990001             0.950163      26.221925
# ...

# %%
# Посмотрим долю данных после обрезки к изначальным данным.
(good_data.shape[0]/data.shape[0])*100
# Out:
# 90.11235955056179

# %% [markdown]
# Убрали выбросы из таблицы `days_exposition` в 45, 60, 30, 90 дней исходя из гипотезы что в эти дни объявления снимаются автоматичеси в случае их непродления~~, а к 0-ю мы привели еще действующие объявления.~~ Обрезали по квантилям данные в столбцах `price_per_square_meter`, `total_area_m2` и `days_exposition` для улучшения качества данных и удаления аномально больших и малых значений в этих столбцах. После всех этих действий, для дальнейшего анализа, оставили 90 % данных от основного набора. Cудя по статистике датафрейма - качество данных улучшилось, каких-то совсем аномальных значений не осталось.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка: Выбросы удалены. Однако ты отфильровал слишком большую долю данных. Стоит удалять не более 10% аномалий. Скорректируй границы для удаления выбросов для сохранения большего обхема строк для последующего анализа.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Написал функцию для обрезки аномальных значений. Добился сохранения 90% от выборки.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Все верно. Так мы можем сохранить больший объем данных для последующего анализа, убрав только самые явные выбросы.
#
# </div>

# %% [markdown]
# ### Факторы влияющие на стоимость квартиры.

# %% [markdown]
# Выясним какие факторы больше всего влияют на стоимость квартиры. Изучим, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучим зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# **Посмотрим корреляции по изучаемым параметрам**

# %%
# Создадим таблицу с данными по корреляции изучаемых параметров.
correlation = good_data[['price_per_square_meter', 'total_area_m2', 'last_price', 'days_exposition','city_center_m', 'number_of_rooms', 'day_of_week_exposition', 'month_exposition', 'year_exposition']].corr()

# %%
# Посмотрим получившиеся данные.
correlation
# Out:
#                         price_per_square_meter  total_area_m2  last_price  \
# price_per_square_meter                1.000000       0.187778    0.684005
# total_area_m2                         0.187778       1.000000    0.785943
# last_price                            0.684005       0.785943    1.000000
# days_exposition                       0.025182       0.158743    0.123893
# city_center_m                        -0.397018      -0.230796   -0.332297
# number_of_rooms                      -0.051448       0.796465    0.493890
# day_of_week_exposition               -0.013036      -0.014028   -0.014859
# month_exposition                      0.003244       0.001637    0.003984
# year_exposition                       0.027685      -0.121016   -0.073107
#
#                         days_exposition  city_center_m  number_of_rooms  \
# price_per_square_meter         0.025182      -0.397018        -0.051448
# total_area_m2                  0.158743      -0.230796         0.796465
# ...

# %%
# Выведем тепловую карту корреляций для наглядности.
plt.figure(figsize = (10,10))
sns.heatmap(correlation, annot=True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Здорово, что ты освоил данный метод 👍
#
# </div>

# %% [markdown]
# Видим что самая большая положительная корреляция между общей площадью и колличеством комнат, что логично. Между ценой квартиры и ее площадью, что так же логично. Ценой за метр и ценой квартиры. Количеством комнат и ценой квартиры.
#
# Видим что самая большая отрицательная корреляция между годом размещения и колличеством дней размещения объявления, что логично.
# Между ценой за кв.м и расстоянием до центра, ценой квартиры и расстоянием до центра и площадью квартиры и расстоянием до центра.

# %% [markdown]
# **Изучим зависимость цены квартиры от ее площади.**

# %%
# Посчитаем коррелицию между количеством комнат и ценой квадратного метра.
good_data['total_area_m2'].corr(good_data['last_price'])
# Out:
# 0.7859426496770372

# %%
# Построим диаграмму разброса.
good_data.plot(kind = 'scatter', y = 'last_price', x = 'total_area_m2', alpha = 0.3, figsize = (10,5), grid = True)
plt.title('Зависимость цены от площади', size=14)
plt.xlabel('Общая площадь, кв.м.')
plt.ylabel('Цена, млн.руб.')
# Out:
# Text(0, 0.5, 'Цена, млн.руб.')

# %% [markdown]
# Наблюдаем положительную кореляцию между ценой квартиры и ее общей площадью. Этого следовало ожидать, чем больше квартира, тем больше ее стоимость.

# %% [markdown]
# **Изучим зависимость цены квартиры от числа комнат.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_rooms_full = good_data.pivot_table(index = 'number_of_rooms', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_rooms_full.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_rooms_full.sort_values('count', ascending = False)
# Out:
#                          mean  count      median
# number_of_rooms
# 1                3.774672e+06   6598   3580000.0
# 2                5.360495e+06   6230   4700000.0
# 3                7.489625e+06   4360   6045738.5
# 4                1.086988e+07    838   8584500.0
# 5                1.482612e+07    192  12000000.0
# 0                2.925253e+06    161   2700000.0
# 6                1.641029e+07     44  16245000.0
# 7                2.029316e+07     19  16800000.0
# 8                2.104500e+07      2  21045000.0
# 10               1.550000e+07      1  15500000.0
# 11               3.300000e+07      1  33000000.0

# %%
# Посчитаем коррелицию между количеством комнат и ценой квартиры.
good_data['number_of_rooms'].corr(good_data['last_price'])
# Out:
# 0.4938902159046841

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_rooms_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от числа комнат', size=14)
plt.xlabel('Число комнат, шт.')
plt.ylabel('Цена квартиры, млн.руб.')
# Out:
# Text(0, 0.5, 'Цена квартиры, млн.руб.')

# %% [markdown]
# Наблюдается положительная корреляция. Это логично, чем больше комнат, тем больше квартира, тем она дороже.

# %% [markdown]
# **Изучим зависимость цены квартиры от этажа.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_floor_category_full = good_data.pivot_table(index = 'floor_category', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_floor_category_full.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_floor_category_full.sort_values('count', ascending = False)
# Out:
#                         mean  count   median
# floor_category
# другой          5.882954e+06  13707  4700000
# последний       5.596534e+06   2511  4250000
# первый          4.439020e+06   2228  3850000

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_floor_category_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от этажа', size=14)
plt.xlabel('Этаж')
plt.ylabel('Цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Цена за метр, руб.')

# %% [markdown]
# По графику видно что самые дешевые квадратные метры на первом этаже, чуть дороже стоят квадратные метры на последних этажах, на остальных(других) этажах квадратные метры самые дорогие.

# %% [markdown]
# **Изучим зависимость цены квартиры от удалённости от центра.**

# %%
# Посмотрим корреляцию между столбцами.
good_data['city_center_m'].corr(good_data['last_price'])
# Out:
# -0.3322965697840895

# %%
# Построим диаграмму разброса.
good_data.plot(kind = 'scatter', y = 'last_price', x = 'city_center_m', alpha = 0.3, figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от удалённости от центра', size=14)
plt.xlabel('Удаленность от цента, м.')
plt.ylabel('Цена квартиры, млн.руб.')
# Out:
# Text(0, 0.5, 'Цена квартиры, млн.руб.')

# %% [markdown]
# Наблюдаем отрицательную корреляцию, это значит что в большинстве случаев увеличение расстояния до центра вызывает снижение цены за квадратный метр. По диаграмме разброса это так же видно.

# %% [markdown]
# **Изучим зависимость цены квартиры от дня размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_weekday_exposition_full = good_data.pivot_table(index = 'day_of_week_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_weekday_exposition_full.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_weekday_exposition_full.sort_values('median', ascending = False)
# Out:
#                                 mean  count   median
# day_of_week_exposition
# 1                       5.703350e+06   3273  4600000
# 3                       5.826582e+06   3413  4599000
# 2                       5.701159e+06   3048  4575000
# 0                       5.704732e+06   2758  4500000
# 5                       5.529527e+06   1474  4500000
# 4                       5.542849e+06   3197  4450000
# 6                       5.491582e+06   1283  4450000

# %%
# Посмотрим корреляцию.
good_data['day_of_week_exposition'].corr(good_data['last_price'])
# Out:
# -0.014859292002076304

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_weekday_exposition_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от дня размещения.', size=14)
plt.xlabel('День недели.')
plt.ylabel('Цена квартиры, руб.')
# Out:
# Text(0, 0.5, 'Цена квартиры, руб.')

# %% [raw]
# По полученным данным сложно найти зависимость между днем недели когда было размещено объявление и ценой квартиры, медианная цена не сильно различается. Видно падение цены к выходным дням, но так же видно что и объявлений размещенных в выходные в 2-3 раза меньше. В целом корреляция минимальна.

# %% [markdown]
# **Изучим зависимость цены квартиры от месяца размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_month_exposition_full = good_data.pivot_table(index = 'month_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_month_exposition_full.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_month_exposition_full.sort_values('median', ascending = False)
# Out:
#                           mean  count   median
# month_exposition
# 9                 5.864120e+06   1689  4650000
# 2                 5.800927e+06   2018  4600000
# 5                 5.786112e+06   1044  4550000
# 11                5.768045e+06   1980  4550000
# 1                 5.730932e+06   1106  4545000
# 4                 5.585008e+06   1407  4500000
# 8                 5.623090e+06   1464  4500000
# 10                5.653609e+06   1810  4500000
# 12                5.620032e+06   1254  4500000
# 3                 5.456161e+06   1793  4490000
# 7                 5.600079e+06   1379  4450000
# 6                 5.521843e+06   1502  4400000

# %%
# Посмотрим корреляцию.
good_data['month_exposition'].corr(good_data['last_price'])
# Out:
# 0.003983799915063424

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_month_exposition_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от месяца размещения.', size=14)
plt.xlabel('Месяц.')
plt.ylabel('Цена квартиры, руб.')
# Out:
# Text(0, 0.5, 'Цена квартиры, руб.')

# %% [markdown]
# Из полученых данных видим что самые низкие цены за квадратный метр фиксируются в Июне, а самые высокие цены Сентябрь и Февраль. Тут сложно понять причины - возможно связано с колебанием курсов валют в эти месяцы, но такой информации у нас нет. С какими-то праздниками или сезоном опусков эти колебания вряд ли связаны. В целом корреляция минимальна.

# %% [markdown]
# **Изучим зависимость цены квартиры от года размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_year_exposition_full = good_data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition_full.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_year_exposition_full.sort_values('median', ascending = False)
# Out:
#                          mean  count   median
# year_exposition
# 2014             8.978233e+06    111  6750000
# 2015             6.583052e+06   1073  5144000
# 2019             5.458093e+06    957  4750000
# 2016             5.826634e+06   2537  4500000
# 2018             5.389629e+06   6581  4500000
# 2017             5.711114e+06   7187  4490000

# %%
# Посмотрим корреляцию.
good_data['year_exposition'].corr(good_data['last_price'])
# Out:
# -0.07310720918022762

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_year_exposition_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от года размещения.', size=14)
plt.xlabel('Год.')
plt.ylabel('Цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Цена за метр, руб.')

# %% [markdown]
# Из полученных данных видим что в 2014 году цена за квадратный метр была на пике. В 2015 году начался резкий обвал цен на жилье, в 2019 году цена начала восстанавливаться. За счет 2014 года наблюдается минимальная отрицательная корреляция близкая к нулю.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от числа комнат.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_rooms = good_data.pivot_table(index = 'number_of_rooms', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_rooms.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_rooms.sort_values('count', ascending = False)
# Out:
#                           mean  count    median
# number_of_rooms
# 1                100029.153380   6598  100000.0
# 2                 93635.084751   6230   91993.0
# 3                 92955.352982   4360   87788.5
# 4                 98800.680191    838   89282.0
# 5                103032.458333    192   90083.0
# 0                108333.322981    161  105555.0
# 6                 99423.045455     44   93154.5
# 7                112180.894737     19  101769.0
# 8                105341.000000      2  105341.0
# 10                71726.000000      1   71726.0
# 11               170015.000000      1  170015.0

# %%
# Посчитаем коррелицию между количеством комнат и ценой квадратного метра.
good_data['number_of_rooms'].corr(good_data['price_per_square_meter'])
# Out:
# -0.05144783097751202

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_rooms.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от числа комнат', size=14)
plt.xlabel('Число комнат, шт.')
plt.ylabel('Цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Цена за метр, руб.')

# %% [markdown]
# Наблюдаем небольшую отрицательную корреляцию, это значит что в большинстве случаев увеличение количества комнат вызывает снижение цены за квадратный метр. По графику видно что дешевле всего квадратный метр стоит в 4-х комнатных квартирах, дальше начинается рост цены, но количество таких квартир не репрезентативно.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от этажа.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_floor_category = good_data.pivot_table(index = 'floor_category', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_floor_category.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_floor_category.sort_values('count', ascending = False)
# Out:
#                          mean  count   median
# floor_category
# другой          100052.890932  13707  97014.0
# последний        89344.691358   2511  87884.0
# первый           80714.594255   2228  80899.5

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_floor_category.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от этажа', size=14)
plt.xlabel('Этаж')
plt.ylabel('Цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Цена за метр, руб.')

# %% [markdown]
# По графику видно что самые дешевые квадратные метры на первом этаже, чуть дороже стоят квадратные метры на последних этажах, на остальных(других) этажах квадратные метры самые дорогие.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от удалённости от центра.**

# %%
# Посмотрим корреляцию между столбцами.
good_data['city_center_m'].corr(good_data['price_per_square_meter'])
# Out:
# -0.3970177714269725

# %%
# Построим диаграмму разброса.
good_data.plot(kind = 'scatter', y = 'price_per_square_meter', x = 'city_center_m', alpha = 0.3, figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от удалённости от центра', size=14)
plt.xlabel('Удаленность от цента, м.')
plt.ylabel('Цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Цена за метр, руб.')

# %% [markdown]
# Наблюдаем отрицательную корреляцию, это значит что в большинстве случаев увеличение расстояния до центра вызывает снижение цены за квадратный метр. По диаграмме разброса это так же видно.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от дня размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_weekday_exposition = good_data.pivot_table(index = 'day_of_week_exposition', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_weekday_exposition.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_weekday_exposition.sort_values('median', ascending = False)
# Out:
#                                 mean  count   median
# day_of_week_exposition
# 2                       96301.081037   3048  94542.5
# 1                       96528.589062   3273  94473.0
# 3                       96850.483153   3413  94294.0
# 0                       96730.551124   2758  94143.5
# 4                       95824.046606   3197  93655.0
# 6                       94954.986750   1283  93093.0
# 5                       95405.400950   1474  92893.0

# %%
# Посмотрим корреляцию.
good_data['day_of_week_exposition'].corr(good_data['price_per_square_meter'])
# Out:
# -0.01303608572380085

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_weekday_exposition.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от дня размещения.', size=14)
plt.xlabel('День недели.')
plt.ylabel('Цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Цена за метр, руб.')

# %% [markdown]
# По полученным данным сложно найти зависимость между днем недели когда было размещено объявление и ценой квадратного метра, медианная цена не сильно различается. Видно падение цены в выходные дни, но так же видно что и объявлений размещенных в выходные в 2-3 раза меньше. В целом корреляция минимальна.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от месяца размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_month_exposition = good_data.pivot_table(index = 'month_exposition', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_month_exposition.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_month_exposition.sort_values('median', ascending = False)
# Out:
#                           mean  count   median
# month_exposition
# 8                 97387.538251   1464  95402.0
# 9                 97819.727057   1689  95273.0
# 1                 97699.441230   1106  95200.5
# 11                96979.820202   1980  94781.0
# 2                 96434.629832   2018  94469.5
# 10                96333.675691   1810  94138.5
# 7                 95722.261059   1379  93439.0
# 12                95038.280702   1254  93181.0
# 3                 95372.767987   1793  93023.0
# 5                 96281.888889   1044  92857.0
# 4                 95253.186212   1407  92680.0
# 6                 94568.691744   1502  92663.0

# %%
# Посмотрим корреляцию.
good_data['month_exposition'].corr(good_data['price_per_square_meter'])
# Out:
# 0.0032438468683519328

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_month_exposition.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от месяца размещения.', size=14)
plt.xlabel('Месяц.')
plt.ylabel('Цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Цена за метр, руб.')

# %% [markdown]
# Из полученых данных видим что самые низкие цены за квадратный метр фиксируются в Апрель, Май, Июнь, а самые высокие цены Январь и Август. Тут сложно понять причины - возможно связано с колебанием курсов валют в эти месяцы, но такой информации у нас нет. С какими-то праздниками или сезоном опусков эти колебания вряд ли связаны. В целом корреляция минимальна.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от года размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_year_exposition = good_data.pivot_table(index = 'year_exposition', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_year_exposition.sort_values('median', ascending = False)
# Out:
#                           mean  count  median
# year_exposition
# 2014             108628.810811    111  104271
# 2019             105294.369906    957  104260
# 2018              96527.524692   6581   95652
# 2017              95050.070544   7187   92307
# 2015              97058.544268   1073   91935
# 2016              94702.714624   2537   91304

# %%
# Посмотрим корреляцию.
good_data['year_exposition'].corr(good_data['price_per_square_meter'])
# Out:
# 0.02768547290370143

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_year_exposition.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от года размещения.', size=14)
plt.xlabel('Год.')
plt.ylabel('Цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Цена за метр, руб.')

# %% [markdown]
# Из полученных данных видим что в 2014 году цена за квадратный метр была на пике. В 2015 году был резкий обвал цен на жилье, в следующие годы цена начала восстанавливаться. Есть небольшая положительная корреляция.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Основные параметры, влияющие на цену кв. метра, изучены. Приведены необходимые графики и значения корреляций. Здорово, что по каждому параметру приведен вывод о его влиянии на цену квартиры.
#
# Метод corr можно применять сразу ко всему датафрейму для получения матрицы корреляций. Также для визуализации данной матрицы корреляций можно использовать метод heatmap из библиотеки seaborn. Будет здорово, если ты сможешь это реализовать.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка: Однако по заданию нас просят проанализировать полную стоимость квартир. Дополни данный раздел анализа. Также проанализируй зависимость цены от площади. Этоо очень важный фактор при формировании цены.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Добавил исследование по цене квартиры, сделал матрицу корреляций, сделал визуализацию данной матрицы c помощью heatmap.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Также все правильно. Именно общую цену нас и просят изучить.
# </div>

# %% [markdown]
# ### Выберем 10 населённых пунктов с наибольшим числом объявлений.

# %% [markdown]
# Выберем 10 населённых пунктов с наибольшим числом объявлений. Посчитаем среднюю цену квадратного метра в этих населённых пунктах. Выделим населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
# Создадим сводную таблицу с населенными пунктами, количеством объявлений и средней ценой квадратного метра.
location_pivot_table = good_data.pivot_table(index = 'location_name', values = 'price_per_square_meter', aggfunc=['count', 'mean'])
location_pivot_table.columns = ['count', 'mean']

# %%
# Сохраним первые 10 населенных пунктов по количеству объявлений.
location_pivot_table = location_pivot_table.sort_values('mean', ascending = False).head(10)
# Выведем результат.
location_pivot_table
# Out:
#                  count           mean
# location_name
# Санкт-Петербург  12389  109265.388571
# Пушкин             284  102424.489437
# Зеленогорск         20  100701.500000
# Сестрорецк         145   99973.055172
# Левашово             1   96997.000000
# Кудрово            395   94108.027848
# Парголово          262   89809.931298
# Стрельна            38   89111.947368
# Мистолово            8   89043.750000
# Мурино             512   85520.607422

# %%
# Покажем данные на графике.
location_pivot_table.plot(y = 'mean', grid = True, figsize = (12,7))
plt.title('10 населённых пунктов с наибольшим числом объявлений.', size=14)
plt.xlabel('Населенный пункт')
plt.ylabel('Средняя цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Средняя цена за метр, руб.')

# %%
# Выведем населенный пункт с самой высокой средней стоимостью квадратного метра.
location_pivot_table[location_pivot_table['mean']==location_pivot_table['mean'].max()]
# Out:
#                  count           mean
# location_name
# Санкт-Петербург  12389  109265.388571

# %%
# Выведем населенный пункт с самой низкой средней стоимостью квадратного метра.
location_pivot_table[location_pivot_table['mean']==location_pivot_table['mean'].min()]
# Out:
#                count          mean
# location_name
# Мурино           512  85520.607422

# %% [markdown]
# Выявлено что самая высокая стоимость жилья из 10 населённых пунктов с самым большим количеством объявлений в Санкт-Петербурге, тогда как самая низкая стоимость в Выборге.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: Результат по ценам в зависимости от местоположения квартир получен, можно привести график зависимости цены от местоположения.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сделал.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Лучше использовать столбчатую диаграмму. Мы работаем с категориальными данными, линейный график для таких целей использовать не стоит.
#
# </div>

# %% [markdown]
# ### Выделим квартиры в Санкт-Петербурге. Создадим столбец с расстоянием до центра в километрах.

# %% [markdown]
# Изучим предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделим квартиры в Санкт-Петербурге. Выясним, какая область входит в центр. Создадим столбец с расстоянием до центра в километрах: округлим до целых значений. После этого посчитаем среднюю цену для каждого километра. Построим график: он должен показывать, как цена зависит от удалённости от центра. Определим границу, где график сильно меняется — это и будет центральная зона.

# %%
# Создаем столбец с расстоянием до центра в км.
good_data['city_center_km'] = good_data['city_center_m']/1000

# %%
# Заполняем пропуски девятками.
good_data['city_center_km'] = good_data['city_center_km'].fillna(999999)

# %%
# Приводим данные в столбце к цельночисленным.
good_data['city_center_km'] = good_data['city_center_km'].astype('int')

# %%
# Создаем сводную таблицу со средними значениями цены за квадратный метр с рабивкой по км.до центра
# по г.Санкт-Петербург, исключим из таблицы значения с девятками которыми заполняли пропуски.
pivot_spb_city_center_km = good_data.query('location_name == "Санкт-Петербург" and city_center_km !=999999').pivot_table(index = 'city_center_km', values = 'price_per_square_meter', aggfunc = 'mean')

# %%
# Посмотрим данные в сводной таблице с сортировкой по индексу(км до центра города).
pivot_spb_city_center_km.sort_index(ascending=True)
# Out:
#                 price_per_square_meter
# city_center_km
# 0                        136461.824561
# 1                        133930.394118
# 2                        121332.538813
# 3                        115125.175532
# 4                        130816.285505
# 5                        134922.574007
# 6                        132890.893491
# 7                        129311.234727
# 8                        116895.807018
# 9                        108806.898577
# 10                       109167.280000
# 11                       104756.037197
# 12                       106996.254823
# 13                       105071.313096
# 14                       103067.867104
# 15                        99926.197067
# 16                        99184.511501
# 17                        93069.222738
# 18                        94104.233577
# 19                        94776.500000
# 20                       102764.631579
# 21                        89548.169935
# ...

# %%
# Построим график цен.
pivot_spb_city_center_km.plot(y = 'price_per_square_meter', figsize = (10,5), grid = True)
plt.title('Цена за квадратный метр в зависимости от удаленности от центра', size=14)
plt.xlabel('Расстояние до центра, км.')
plt.ylabel('Средняя цена за метр, руб.')
# Out:
# Text(0, 0.5, 'Средняя цена за метр, руб.')

# %% [markdown]
# Рассмотрев данные из сводной таблицы и графика можно предположить что центральная зона находится в пределах 7 км. от центра. Есть странный провал в районе 3 км, но на 4-м км. цена резко возрастает. Сложно сказать чем это обусловлено. В целом - чем дальше от центра тем дешевле цена квадратного метра. На 27-м км наблюдается резкий скачек цены, не зная о каком конкретно месте идет речь - сложно сказать чем это обусловлено, скорее всего какой-нибудь элитный поселок.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Да, именно эту границу мы можем назвать границей центральной части области.
#
# </div>

# %% [markdown]
# ### Анализ предложений в центре Санк-Петербурга.

# %% [markdown]
# Выделим сегмент квартир в центре. Проанализируем эту территорию и изучим следующие параметры: площадь, цена, число комнат, высота потолков. Также выделим факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделаем выводы. Отличаются ли они от общих выводов по всей базе?

# %%
# Создадим таблицу с данными по центральной части Санкт-Петербурга.
center_spb_good_data = good_data.query('city_center_km <= 7 and location_name == "Санкт-Петербург"')

# %% [markdown]
# Изучим статистику по столбцам `number_of_rooms`, `floor`, `total_area_m2`, `price_per_square_meter`, `ceiling_height_m` в таблицах с общими данными и данными по центру Санк-Петербурга.

# %%
good_data[['number_of_rooms', 'floor', 'total_area_m2', 'price_per_square_meter', 'ceiling_height_m']].describe()
# Out:
#        number_of_rooms         floor  total_area_m2  price_per_square_meter  \
# count     18446.000000  18446.000000   18446.000000            18446.000000
# mean          1.999566      5.991380      57.136620            96259.439011
# std           0.990001      4.941499      26.221925            34445.016211
# min           0.000000      1.000000      13.000000             7962.000000
# 25%           1.000000      2.000000      39.200000            76897.500000
# 50%           2.000000      4.000000      50.400000            94076.000000
# 75%           3.000000      8.000000      67.200000           111911.250000
# max          11.000000     33.000000     226.000000           321739.000000
#
#        ceiling_height_m
# count      10997.000000
# mean           2.751260
# std            0.935914
# min            1.000000
# 25%            2.520000
# 50%            2.650000
# 75%            2.800000
# max           27.500000

# %%
center_spb_good_data[['number_of_rooms', 'floor', 'total_area_m2', 'price_per_square_meter', 'ceiling_height_m']].describe()
# Out:
#        number_of_rooms        floor  total_area_m2  price_per_square_meter  \
# count      2708.000000  2708.000000    2708.000000             2708.000000
# mean          2.636632     4.245199      80.910487           129111.125554
# std           1.229253     3.097074      37.573949            44918.940126
# min           0.000000     1.000000      13.000000            15345.000000
# 25%           2.000000     2.000000      53.000000            97912.500000
# 50%           3.000000     4.000000      73.000000           119382.500000
# 75%           3.000000     5.000000      99.000000           148235.000000
# max          11.000000    25.000000     226.000000           321739.000000
#
#        ceiling_height_m
# count       1696.000000
# mean           3.066545
# std            0.677591
# min            2.400000
# 25%            2.800000
# 50%            3.000000
# 75%            3.200000
# max           27.000000

# %% [markdown]
# - По количеству комнат в предложениях данные примерно одинаковые, видим что в центре среднее количество комнат немного больше.
# - В центре этажность ниже чем в целом по выборке.
# - Площадь квартир в центре больше чем в целом по выборке.
# - Цена за квадратный метр, как и ожидалось, в центре выше чем в целом по выборке.
# - Высота потолков в центре выше чем в целом по выборке.

# %% [markdown]
# **Посмотрим корреляции по изучаемым параметрам**

# %%
# Создадим таблицу с данными по корреляции изучаемых параметров.
correlation_spb = center_spb_good_data[['price_per_square_meter', 'total_area_m2', 'last_price', 'days_exposition','city_center_m', 'number_of_rooms', 'day_of_week_exposition', 'month_exposition', 'year_exposition']].corr()

# %%
# Посмотрим получившиеся данные.
correlation_spb
# Out:
#                         price_per_square_meter  total_area_m2  last_price  \
# price_per_square_meter                1.000000       0.048195    0.649107
# total_area_m2                         0.048195       1.000000    0.742571
# last_price                            0.649107       0.742571    1.000000
# days_exposition                       0.011610       0.166724    0.114645
# city_center_m                         0.053218      -0.169257   -0.062782
# number_of_rooms                      -0.193385       0.794828    0.439734
# day_of_week_exposition               -0.000996      -0.015762   -0.017757
# month_exposition                     -0.018539      -0.011538   -0.012631
# year_exposition                       0.048064      -0.131848   -0.064531
#
#                         days_exposition  city_center_m  number_of_rooms  \
# price_per_square_meter         0.011610       0.053218        -0.193385
# total_area_m2                  0.166724      -0.169257         0.794828
# ...

# %%
# Выведем тепловую карту корреляций для наглядности.
plt.subplots_adjust(right=1, bottom=0.1, top=0.9)
plt.figure(figsize = (20,20))
plt.subplot(221)
sns.heatmap(correlation_spb, annot=True)
plt.title('Корреляция Спб', size=14)
plt.subplot(222)
sns.heatmap(correlation, annot=True)
plt.title('Корреляция общая', size=14)
# Out:
# Text(0.5, 1, 'Корреляция общая')

# %% [markdown]
# В целом картина схожа с общей выборкой за исключением корреляции цены к удаленности от центра, что логично, т.к. рассматриваем центр Санкт-Петербурга.

# %% [markdown]
# **Изучим зависимость цены квартиры от ее площади.**

# %%
# Посчитаем коррелицию между количеством комнат и ценой квадратного метра.
center_spb_good_data['total_area_m2'].corr(center_spb_good_data['last_price'])
# Out:
# 0.7425710035588609

# %%
# Построим диаграмму разброса.
center_spb_good_data.plot(kind = 'scatter', y = 'last_price', x = 'total_area_m2', figsize = (10,5), alpha = 0.3, grid = True)
plt.title('Зависимость цены от площади СпБ', size=14)
plt.xlabel('Общая площадь, кв.м.')
plt.ylabel('Цена, млн.руб.')
plt.show()
good_data.plot(kind = 'scatter', y = 'last_price', x = 'total_area_m2', figsize = (10,5), alpha = 0.3, grid = True)
plt.title('Зависимость цены от площади', size=14)
plt.xlabel('Общая площадь, кв.м.')
plt.ylabel('Цена, млн.руб.')
plt.show()

# %% [markdown]
# Наблюдаем положительную кореляцию между ценой квартиры и ее общей площадью. Этого следовало ожидать, чем больше квартира, тем больше ее стоимость. Картина по Санкт-Петербургу ничем не отличается от общей выборки.

# %% [markdown]
# **Изучим зависимость цены квартиры от числа комнат.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_rooms_full_spb = center_spb_good_data.pivot_table(index = 'number_of_rooms', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_rooms_full_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_rooms_full_spb.sort_values('count', ascending = False)
# Out:
#                          mean  count    median
# number_of_rooms
# 2                8.468479e+06    854   7300000
# 3                1.194774e+07    844   9400000
# 1                6.255818e+06    459   5900000
# 4                1.427340e+07    348  11285000
# 5                1.655309e+07    134  12600000
# 6                1.711236e+07     36  16520000
# 7                2.098167e+07     18  17400000
# 0                4.755091e+06     11   3200000
# 8                2.104500e+07      2  21045000
# 10               1.550000e+07      1  15500000
# 11               3.300000e+07      1  33000000

# %%
# Посчитаем коррелицию между количеством комнат и ценой квартиры.
center_spb_good_data['number_of_rooms'].corr(center_spb_good_data['last_price'])
# Out:
# 0.4397335414741707

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_rooms_full_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от числа комнат Спб', size=14)
plt.xlabel('Число комнат, шт.')
plt.ylabel('Цена квартиры, млн.руб.')
plt.show()
pivot_table_rooms_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от числа комнат', size=14)
plt.xlabel('Число комнат, шт.')
plt.ylabel('Цена квартиры, млн.руб.')
plt.show()

# %% [markdown]
# Наблюдается положительная корреляция. Это логично, чем больше комнат, тем больше квартира, тем она дороже. Ситуация аналогична общей выборке.

# %% [markdown]
# **Изучим зависимость цены квартиры от этажа.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_floor_category_full_spb = center_spb_good_data.pivot_table(index = 'floor_category', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_floor_category_full_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_floor_category_full_spb.sort_values('count', ascending = False)
# Out:
#                         mean  count   median
# floor_category
# другой          1.094650e+07   1946  8750000
# последний       1.067711e+07    462  8492000
# первый          7.581806e+06    300  5999500

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_floor_category_full_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от этажа Спб', size=14)
plt.xlabel('Этаж')
plt.ylabel('Цена за метр, руб.')
plt.show()
pivot_table_floor_category_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от этажа', size=14)
plt.xlabel('Этаж')
plt.ylabel('Цена за метр, руб.')
plt.show()

# %% [markdown]
# По графику видно что самые дешевые квартиры на первом этаже, квартиры на последнем этаже в центре Санкт-Петербурга, в отличие от общей выборки не сильно отличаются по цене от квартир на остальных(других) этажах.

# %% [markdown]
# **Изучим зависимость цены квартиры от удалённости от центра.**

# %%
# Посмотрим корреляцию между столбцами.
center_spb_good_data['city_center_m'].corr(center_spb_good_data['last_price'])
# Out:
# -0.06278242337960858

# %%
# Построим диаграмму разброса.
center_spb_good_data.plot(kind = 'scatter', y = 'last_price', x = 'city_center_m', alpha = 0.3, figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от удалённости от центра Спб', size=14)
plt.xlabel('Удаленность от цента, м.')
plt.ylabel('Цена квартиры, млн.руб.')
plt.show()
good_data.plot(kind = 'scatter', y = 'last_price', x = 'city_center_m', alpha = 0.3, figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от удалённости от центра', size=14)
plt.xlabel('Удаленность от цента, м.')
plt.ylabel('Цена квартиры, млн.руб.')
plt.show()

# %% [markdown]
# В отличие от общей выборки - в центре Санкт Петербурга не наблюдается зависимости цены квартиры от расстояния до центра. Корреляция почти нулевая.

# %% [markdown]
# **Изучим зависимость цены квартиры от дня размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_weekday_exposition_full_spb = center_spb_good_data.pivot_table(index = 'day_of_week_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_weekday_exposition_full_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_weekday_exposition_full_spb.sort_values('median', ascending = False)
# Out:
#                                 mean  count   median
# day_of_week_exposition
# 0                       1.104940e+07    408  8651500
# 6                       1.078595e+07    149  8641044
# 2                       1.060931e+07    450  8492393
# 4                       1.032841e+07    445  8400000
# 1                       1.037974e+07    468  8282475
# 3                       1.037889e+07    587  8270000
# 5                       1.031611e+07    201  7690000

# %%
# Посмотрим корреляцию.
center_spb_good_data['day_of_week_exposition'].corr(center_spb_good_data['last_price'])
# Out:
# -0.017756630744170613

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_weekday_exposition_full_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от дня размещения Спб.', size=14)
plt.xlabel('День недели.')
plt.ylabel('Цена квартиры, руб.')
plt.show()
pivot_table_weekday_exposition_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от дня размещения.', size=14)
plt.xlabel('День недели.')
plt.ylabel('Цена квартиры, руб.')
plt.show()

# %% [markdown]
# Как и по общей выборке наблюдается почти нулевая корреляция цены квартиры к дню размещения. Квартиры высталенные на продажу в субботу стоят дешевле всего, выставленные в воскресенье и понедельник - дороже всего.

# %% [markdown]
# **Изучим зависимость цены квартиры от месяца размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_month_exposition_full_spb = center_spb_good_data.pivot_table(index = 'month_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_month_exposition_full_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_month_exposition_full_spb.sort_values('median', ascending = False)
# Out:
#                           mean  count   median
# month_exposition
# 9                 1.043107e+07    266  8765000
# 1                 1.096686e+07    150  8725000
# 11                1.118154e+07    282  8640000
# 2                 1.140305e+07    287  8500000
# 3                 1.040711e+07    253  8500000
# 7                 1.072174e+07    214  8400000
# 10                1.065988e+07    247  8370000
# 6                 1.015971e+07    242  8225000
# 5                 9.863339e+06    171  8100000
# 8                 1.003741e+07    212  7992500
# 4                 1.005781e+07    200  7953910
# 12                9.883055e+06    184  7500000

# %%
# Посмотрим корреляцию.
center_spb_good_data['month_exposition'].corr(center_spb_good_data['last_price'])
# Out:
# -0.012631037073695546

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_month_exposition_full_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от месяца размещения Спб.', size=14)
plt.xlabel('Месяц.')
plt.ylabel('Цена квартиры, руб.')
plt.show()
pivot_table_month_exposition_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от месяца размещения.', size=14)
plt.xlabel('Месяц.')
plt.ylabel('Цена квартиры, руб.')
plt.show()

# %% [markdown]
# Из полученых данных видим что самые низкие цены за квадратный метр фиксируются в декабре, апреле и августе, а самые высокие цены сентябрь и январь. В целом корреляция минимальна как и в общей выборке.

# %% [markdown]
# **Изучим зависимость цены квартиры от года размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_year_exposition_full_spb = center_spb_good_data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition_full_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_year_exposition_full_spb.sort_values('median', ascending = False)
# Out:
#                          mean  count    median
# year_exposition
# 2014             1.570085e+07     20  14972000
# 2016             1.069522e+07    457   8800000
# 2015             1.096331e+07    274   8710840
# 2017             1.076366e+07   1078   8425000
# 2018             9.983933e+06    775   8100000
# 2019             9.257740e+06    104   7500000

# %%
# Посмотрим корреляцию.
center_spb_good_data['year_exposition'].corr(center_spb_good_data['last_price'])
# Out:
# -0.06453053283889798

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_year_exposition_full_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от года размещения Спб.', size=14)
plt.xlabel('Год.')
plt.ylabel('Цена за метр, млн. руб.')
plt.show()
pivot_table_year_exposition_full.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квартиры от года размещения.', size=14)
plt.xlabel('Год.')
plt.ylabel('Цена за метр, руб.')
plt.show()

# %% [markdown]
# Наблюдается небольшая отрицательная корреляция. Как и общей выборке - цены были на пике в 2014, в 2015 резко упали. В отличие от общей выборке - цены на квартиры в центре Санкт-Петербурга так и не начали восстанавливаться в 2019, а только сильнее просели.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от числа комнат.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_rooms_spb = center_spb_good_data.pivot_table(index = 'number_of_rooms', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_rooms_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_rooms_spb.sort_values('count', ascending = False)
# Out:
#                           mean  count    median
# number_of_rooms
# 2                130981.583138    854  122085.0
# 3                126843.536730    844  111314.5
# 1                144985.673203    459  139929.0
# 4                119012.942529    348  105656.0
# 5                111691.567164    134   93902.0
# 6                102301.416667     36   93384.5
# 7                116235.111111     18  106467.0
# 0                141782.454545     11  136563.0
# 8                105341.000000      2  105341.0
# 10                71726.000000      1   71726.0
# 11               170015.000000      1  170015.0

# %%
# Посчитаем коррелицию между количеством комнат и ценой квадратного метра.
center_spb_good_data['number_of_rooms'].corr(center_spb_good_data['price_per_square_meter'])
# Out:
# -0.19338548414633253

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_rooms_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от числа комнат Спб', size=14)
plt.xlabel('Число комнат, шт.')
plt.ylabel('Цена за метр, руб.')
plt.show()
pivot_table_rooms.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от числа комнат', size=14)
plt.xlabel('Число комнат, шт.')
plt.ylabel('Цена за метр, руб.')
plt.show()

# %% [markdown]
# Наблюдаем более сильную отрицательную корреляцию чем по общей выборке, это значит что в большинстве случаев увеличение количества комнат вызывает более сильное снижение цены за квадратный метр в центре Санкт-Петербурге чем в целом по выборке. Так же видим что в центре предложение 2-х, 3-х комнатных квартир больше чем 1 комнатных. В центре Санкт-Петербурга дешевле всего квадратный метр стоит в 5-6 комнатных квартирах, в общем по выборке в 3-4 комнатных.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от этажа.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_floor_category_spb = center_spb_good_data.pivot_table(index = 'floor_category', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_floor_category_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_floor_category_spb.sort_values('count', ascending = False)
# Out:
#                          mean  count    median
# floor_category
# другой          133305.513875   1946  124158.0
# последний       122178.712121    462  112727.0
# первый          112579.443333    300  106097.5

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_floor_category_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от этажа', size=14)
plt.xlabel('Этаж')
plt.ylabel('Цена за метр, руб.')
plt.show()
pivot_table_floor_category.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от этажа Спб', size=14)
plt.xlabel('Этаж')
plt.ylabel('Цена за метр, руб.')
plt.show()

# %% [markdown]
# Для центра Санкт-Петербурга выводи такие же что и в целом по общей выборке. На первом этаже самые дешевые квартиры, чуть дороже на последнем этаже, на остальных этажах квадратные метры значительно дороже.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от удалённости от центра.**

# %%
# Посмотрим корреляцию между столбцами.
center_spb_good_data['city_center_m'].corr(center_spb_good_data['price_per_square_meter'])
# Out:
# 0.053218001606050606

# %%
# Построим диаграмму разброса.
center_spb_good_data.plot(kind = 'scatter', y = 'price_per_square_meter', x = 'city_center_m', alpha = 0.3, figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от удалённости от центра Спб', size=14)
plt.xlabel('Удаленность от цента, м.')
plt.ylabel('Цена за метр, руб.')
plt.show()
good_data.plot(kind = 'scatter', y = 'price_per_square_meter', x = 'city_center_m', alpha = 0.3, figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от удалённости от центра', size=14)
plt.xlabel('Удаленность от цента, м.')
plt.ylabel('Цена за метр, руб.')
plt.show()

# %% [markdown]
# В центре Санкт-Петербурга, в отличие от общей выборки, наблюдается минимальная корреляция цены квадрантного метра к удаленности от центра. В принципе, этого стоило ожидать, на то он и центр.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от дня размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_weekday_exposition_spb = center_spb_good_data.pivot_table(index = 'day_of_week_exposition', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_weekday_exposition_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_weekday_exposition_spb.sort_values('median', ascending = False)
# Out:
#                                  mean  count    median
# day_of_week_exposition
# 5                       133539.308458    201  125000.0
# 0                       131666.352941    408  122281.0
# 4                       128903.442697    445  121428.0
# 2                       129803.562222    450  120260.5
# 1                       127175.920940    468  117259.0
# 6                       128513.248322    149  117105.0
# 3                       127140.059625    587  116291.0

# %%
# Посмотрим корреляцию.
center_spb_good_data['day_of_week_exposition'].corr(center_spb_good_data['price_per_square_meter'])
# Out:
# -0.000995563034578438

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_weekday_exposition_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от дня размещения Спб.', size=14)
plt.xlabel('День недели.')
plt.ylabel('Цена за метр, руб.')
plt.show()
pivot_table_weekday_exposition.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от дня размещения.', size=14)
plt.xlabel('День недели.')
plt.ylabel('Цена за метр, руб.')
plt.show()

# %% [markdown]
# По количеству размещенных объявлений по дням недели в центре Санкт-Петербурге ситуация не сильно отличается от общей выборки.
# В выходные дни объявлений размещается меньше чем в будни. С ценами уже есть разница, самые дорогие предложения размещали в субботу, самые дешевые в воскресенье и четверг. В целом корреляция минимальна.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от месяца размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_month_exposition_spb = center_spb_good_data.pivot_table(index = 'month_exposition', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_month_exposition_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_month_exposition_spb.sort_values('median', ascending = False)
# Out:
#                            mean  count    median
# month_exposition
# 1                 134185.800000    150  128953.5
# 3                 132950.581028    253  126808.0
# 8                 128387.797170    212  123556.5
# 9                 127931.642857    266  121523.0
# 10                129113.493927    247  119718.0
# 12                125982.885870    184  119321.5
# 11                131561.595745    282  118873.0
# 2                 130657.243902    287  117926.0
# 7                 128823.023364    214  116204.0
# 5                 125983.812865    171  116150.0
# 4                 125198.950000    200  115777.0
# 6                 127266.524793    242  114816.5

# %%
# Посмотрим корреляцию.
center_spb_good_data['month_exposition'].corr(center_spb_good_data['price_per_square_meter'])
# Out:
# -0.018539127840337358

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_month_exposition_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от месяца размещения Спб.', size=14)
plt.xlabel('Месяц.')
plt.ylabel('Цена за метр, руб.')
plt.show()
pivot_table_month_exposition.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от месяца размещения.', size=14)
plt.xlabel('Месяц.')
plt.ylabel('Цена за метр, руб.')
plt.show()

# %% [markdown]
# Сравнивая цены с рабивкой по месяцам в центре с общей выборкой можно сказать, что в августе и январе цены за квадратный метр растут, в период с апреля по июнь падают. Немгого выбиваются данные за март и просадка в феврале в данных по центру Санкт-Петербурга. В целом корреляция минимальна.

# %% [markdown]
# **Изучим зависимость цены квадратного метра от года размещения.**

# %%
# Создадим сводную таблицу для дальнейших расчетов.
pivot_table_year_exposition_spb = center_spb_good_data.pivot_table(index = 'year_exposition', values = 'price_per_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition_spb.columns = ['mean', 'count', 'median']

# %%
# Посмотрим получившуюся сводную таблицу.
pivot_table_year_exposition_spb.sort_values('median', ascending = False)
# Out:
#                           mean  count    median
# year_exposition
# 2014             146645.800000     20  137227.5
# 2019             139222.826923    104  135676.0
# 2018             130634.899355    775  122115.0
# 2017             128710.062152   1078  118892.5
# 2016             128099.553611    457  115000.0
# 2015             122948.350365    274  113127.5

# %%
# Посмотрим корреляцию.
center_spb_good_data['year_exposition'].corr(center_spb_good_data['price_per_square_meter'])
# Out:
# 0.04806433929593494

# %%
# Построим график по значениям сводной таблицы по медианной цене.
pivot_table_year_exposition_spb.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от года размещения.', size=14)
plt.xlabel('Год.')
plt.ylabel('Цена за метр, руб.')
plt.show()
pivot_table_year_exposition.plot(y = 'median', figsize = (10,5), grid = True)
plt.title('Зависимость цены квадратного метра от года размещения.', size=14)
plt.xlabel('Год.')
plt.ylabel('Цена за метр, руб.')
plt.show()

# %% [markdown]
# Как и в общей выборке, цена квадратного метра резко падает после 2014 года. С 2016 года растет. На фоне стабильного падения общей цены - эти данные выглядят интересно. Видимо после 2014 предложение больших квартир в центре Санкт-Петербурга сократилось. В целом корреляция минимальна.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка: Опять же проанализируй и полную стоимость квартир и влияние признаков на данный параметр.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Будет здорово, если ты построишь параметры для центра и для остальной части города на одном рисунке. Так различия в данных будет легче обнаружить.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Добавил исследование по цене квартиры, сделал матрицу корреляций, сделал визуализацию данной матрицы c помощью heatmap, добавил графики по общей выборке.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Классный анализ вышел. Характерные черты центральной части города определены.
#
# </div>

# %% [markdown]
# ## Общий вывод.

# %% [markdown]
# В данном проекте были обработаны данные по объявлениям по продаже недвижимости размещенных на площадке `Яндекс Недвижимость` за 2014 - 2019 года.
#
# Там где это было необходимо, были заполнены пропуски и изменены типы данных.
#
# Были посчитаны и добавлены в датафрейм:
# - стоимость квадратного метра.
# - год размещения объявления.
# - месяц размещения объявления.
# - день размещения объявления.
# - разбивку по категориям этажей квартир.
# - соотношение площадей в квартирах(жилая\кухня\общая).
#
# Изучили параметры площадь, цена, число комнат, высота потолков на предмет выбивающихся значений и аномалий.
# Было выявлено, что большое количество объявлений были сняты автоматически. Обрезали выбивающиеся значения, выявленные с помощью диаграмм размаха, по квантилям. Создали отдельный датафрейм куда записали данные без этих аномалий и выбивающихся значений.
#
# В ходе дальнейшего изучения получившегося датафрейма было выявлено:
# - Нормальные значения времени продаж варьируется от 1 до, примерно, 600 дней.
# - На стоимость квадратного метра сильнее всего влияют - количество комнат, этаж квартиры. В случае с общей выборкой - удаленность от центра.
# - На стоимость квартиры в целом сильнее всего влияют ее размер, цена квадратного метра, этаж. В случае с общей выборкой - удаленность от центра.
# - Удаленность от центра влияет на стоимость квадратного метра, правда в самом центральном районе(в пределах 7км от центра), эта зависимость не прослеживается.
# - В 2014 году цена квадратного метра была на пике, потом начался резкий обвал цены квадратного метра, в 2017 году цены начали восстанавливаться. В центре Санкт-Петербурга выявлена аномалия в разрезе восстановления цен после падения 2014 - цена за квадратный метр растет, но общая стоимость квартир постоянно падает. Возможно в центре Санкт-Петербурга в предложениях жилья остались только небольшие квартиры.
# - Корреляция между днем недели, месяцем размещения и ценой квадратного метра и общей стоимостью квартиры - минимальна.
#
# Пожелания по улучшению качества данных по продажам недвижимости:
# - Указывать адрес объекта недвижимости с привязкой к местности. Это помогло бы решить проблемы с пропусками в населенных пунктах, в этажности домов, в высоте потолков(очень редко бывает так что в одном и том же доме в квартирах потолки разной высоты), в расстоянии до центра, в расстоянии до аэропорта, в расстоянии до парка, в расстоянии до водоема, в жилой площади и площади кухни(квартиры в домах обычно типовые).
# - Указывать отдельно от названия тип населенного пункта(город, село, поселок и т.д). Сделать для клиентов соответствующий выпадающий список без возможности заполнения этих пунктов вручную.
# - Указывать тип недвижимости(квартира, дом, участок, гараж, склад и тд.). Очень вероятно что ряд аномальных значений можно было бы логично объяснить зная эту информацию.
# - Указывать информацию об автоматическом снятии объявления. Если объявление было снято автоматически - скорее всего продажа не состоялась.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Выводы описаны грамотно. Приведены ответы на главные вопросы проекта. В выводах можно приводить полученные ранее значения, правильно. Здорово, что по каждому пункту работы приведен вывод.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Если тебе нравится тема визуализации, то можешь изучить и методы библиотеки seaborn. Она позволяет строить довольно презентабельные графики. Рекомендую ресурс https://www.python-graph-gallery.com/. В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
#
# Ты проделал большую работу, молодец! Ты овладел важными на данном этапе обучения инструментами, а также довольно качественно их используешь. Критических замечаний немного. Однако их важно исправить. Также есть достаточное число желтых комментариев. Думаю, исправить и их тебе не составит труда. Жду твою работу :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Помарки исправлены, и теперь работа выполнена хорошо. У тебя вышел очень крутой проект, молодец. Продолжай в том же духе. Спасибо за оставленные комментарии по исправлениям. Успехов в дальнейших проектах :)
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
